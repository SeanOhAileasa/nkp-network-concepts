# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-network-concepts/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Common Ports``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# <a id="topAdvancedNetworking"></a>
# ### [Common Ports](#networkConcepts)

# %% [markdown]
# - Telecommunication Network (Telnet) ``tcp/23`` <br/>
# - Secure Shell (SSH) ``tcp/22`` <br/>
# - Domain Name System (DNS) ``udp/53`` <br/>
# - [Email Transfer] Simple Mail Transfer Protocol (SMTP) ``tcp/25``  <br/>
# 	- (Email Receive: IMAP4 ``tcp/143`` - POP3 ``tcp/110``) <br/>
# - Secure File Transfer Protocol (SFTP) ``tcp/22``  <br/>
# 	- (Encrypted SSH Protocol as the underlying communication) <br/>
# - File Transfer Protocol ``tcp/20`` (active mode data) ``tcp/21`` (control) <br/>
# - Trival File Transfer Protcol ``udp/69``	 <br/>
# - Dynamic Host Configuration Protocol (DHCP) ``udp/67`` ``udp/68`` <br/>
# - Hypertext Transfer Protocol (HTTP) ``tcp/80``  <br/>
# 	- Hypertext Transfer Protocol Secure (HTTPS) ``tcp/443`` <br/>
# - Simple Network Management Protocol (SNMP) ``udp/161`` <br/>
# - Remote Desktop Protocol (RDP) ``tcp/3389`` <br/>
# - Network Time Protocol (NTP) ``udp/123`` <br/>
# - Session Initiation Protocol (SIP) ``tcp/5060`` ``tcp/5061`` <br/>
# - Server Message Block (SMB) ``tcp/445`` <br/>
# 	(Common Internet File System - CIFS) <br/>
# - [Email Receive] Post Office Protocol v3 (POP3) ``tcp/110`` <br/>
# 	- [Email Receive] Internet Message Access Protocol v4 (IMAP4) ``tcp/143`` <br/>
# - Lightweight Directory Access Protocol (LDAP) ``tcp/389`` <br/>
# 	- Lightweight Directory Access Protocol Secure (LDAPS) ``tcp/636`` <br/>
# - H.323 ``tcp/1720`` <br/>

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkConcepts"></a>
# ***
# ### Common Ports
# ***

# %% [markdown]
# We know that our applications communicate across the network using well known port numbers.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Telecommunication Network (Telnet) ``tcp/23``
# ***

# %% [markdown]
# Telnet stands for telecommunication network, it uses TCP port 23 as it's well known port number.

# %% [markdown]
# Telnet is a way to be able to log into devices remotely and be able to access them from this text based console.

# %% [markdown]
# It's a way to communicate to servers, routers, switches and other infrastructure devices to be able to administer those machines.

# %% [markdown]
# But all of this telnet communication is sent in a non encrypted form. Your username and your password are sent in the clear across the network, if anyone happens to be listening in or can gather those packets, and they'll be able to find all of your usernames and all of your passwords.

# %% [markdown]
# And that's why most people will not use telnet as a way to manage these devices on a modern network.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Secure Shell (SSH) ``tcp/22``
# ***

# %% [markdown]
# As an alternative to tell that most system administrators will use SSH or secure shell.

# %% [markdown]
# SSH uses TCP port 22 as its well known port number, and it uses this port number two send encrypted communication back and forth to these infrastructure devices.

# %% [markdown]
# It has the same look and feel as the Telnet console, but an SSH console is sending all communication as encrypted data, including your username and your password.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Domain Name System (DNS) ``udp/53``
# ***

# %% [markdown]
# DNS is the domain name system, and it's a protocol that most people don't even realise is going over their network, because all of the communication happens behind the scenes.

# %% [markdown]
# One of the primary roles of DNS is to convert the names that we use, for instance, inside of a browser to something that the network can use, such as an IP address.

# %% [markdown]
# So if you're in a browser and you type in www.professormesser.com, your machine goes out to a DNS server to request the IP address of my device and it may return an IP address such as ``162.159.246.164``.

# %% [markdown]
# It's using UDP port 53 to be able to perform that communication.

# %% [markdown]
# These are obviously very critical resources, we don't commonly remember the IP address of a server that we might be using. So instead, we use our DNS servers to take the name that we can remember and convert it to an IP address that can be used across the network.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### [Email Transfer] Simple Mail Transfer Protocol (SMTP) ``tcp/25`` - (Email Receive: IMAP - POP3)
# ***

# %% [markdown]
# Another popular protocol on our networks is SMTP.

# %% [markdown]
# This is the Simple Mail Transfer Protocol and it uses port 25 over TCP to be able to send mail communications from one mail server to another.

# %% [markdown]
# We also commonly use SMTP to send mail from our devices to a mail server for outgoing mail. So you may commonly configure an SMTP in your mail client or on your mobile device to be able to send that outgoing mail.

# %% [markdown]
# Other protocols are commonly used for incoming mail.

# %% [markdown]
# And you may see protocols such as IMAP, or pop three used for all of your incoming mail communication.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Secure File Transfer Protocol (SFTP) ``tcp/22`` (Encrypted SSH Protocol as the underlying communication)
# ***

# %% [markdown]
# There are many different ways to send files across our network.

# %% [markdown]
# One of these methods uses a protocol named SFTP - stands for secure file transfer protocol.

# %% [markdown]
# And it uses SSH as the underlying protocol to make this happen. So it uses exactly the same port number as SSH, or TCP port 22.

# %% [markdown]
# SFTP is also a full featured File Transfer Protocol, it can only transfer the files, but it can resume if the transfer happens to be interrupted. It can provide you with a directory listing, it can do remote file removals, and much more.

# %% [markdown]
# And of course, since we're using the encrypted SSH protocol as the underlying communication, we know that all of this file transfer information will be encrypted across the network.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### File Transfer Protocol ``tcp/20`` (active mode data) ``tcp/21`` (control)
# ***

# %% [markdown]
# If you don't need encrypted communication for your file transfers, you may want to use FTP or the File Transfer Protocol.

# %% [markdown]
# FTP may use two different protocols to be able to transfer files:
#
#
# i. may use TCP port 20 to provide an active mode data transfer;
#
#
# ii. may use TCP port 21 as the control information between the client and the server.

# %% [markdown]
# FTP is going to transfer these files and it's going to require some type of authentication with a username and password to be able to log into the FTP server.

# %% [markdown]
# This also has a full set of features similar to SFTP, allowing you to list the files that are available on a device you can add other files, rename files and delete any files from the file system.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Trival File Transfer Protcol ``udp/69``
# ***

# %% [markdown]
# If you need a very simple form of file transfer, then you may want to use TFTP - stands for Trivial File Transfer Protocol and it uses UDP port 69.

# %% [markdown]
# It's very simple way to communicate because it doesn't require any type of authentication. So you won't need a username and password to be able to transfer these files.

# %% [markdown]
# Since there's no authentication and no encryption used for TFTP. It's not something that would be used for important data or used on production systems.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Dynamic Host Configuration Protocol (DHCP) ``udp/67`` ``udp/68``
# ***

# %% [markdown]
# When you start your computer, it's able to get an IP address automatically using DHCP, or the Dynamic Host Configuration Protocol.

# %% [markdown]
# This is an automated process that assigns your IP address your subnet mask, your DNS settings, and many other options within your IP configuration.

# %% [markdown]
# It uses UDP port 67, and UDP port 68 to communicate, and you also somewhere on your network need a DHCP server. This might be a standalone server, or it might be a service that's integrated into the router that you use on your wireless network.

# %% [markdown]
# DHCP commonly has a pool of IP addresses configured inside of the DHCP server. And as devices connect to the network, they're given whatever might be available inside of that pool.

# %% [markdown]
# There's also a leased time associated with these IP addresses. So the device either has to release the same IP address or once that lease expires the IP address that becomes available for someone else on the network.

# %% [markdown]
# You can also configure reservations within the DHCP server so that certain devices will always get the same IP addresses. It's common to do that with servers and other infrastructure devices. This also makes it very easy if you need to change the IP addresses on a number of devices. Instead of going to each individual device, you simply log into your DHCP server and you change the DHCP reservations there.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Hypertext Transfer Protocol (HTTP) ``tcp/80`` and Hypertext Transfer Protocol Secure (HTTPS) ``tcp/443``
# ***

# %% [markdown]
# Two of the most popular protocols you'll find on your network is HTTP, and HTTPS.

# %% [markdown]
# The stands for Hypertext Transfer Protocol, and Hypertext Transfer Protocol Secure.

# %% [markdown]
# These are two protocols that are commonly used by our browsers. Other applications may also use HTTP and HTTPS. Even if they're applications that don't run inside of a browser.

# %% [markdown]
# TRraffic that is sent through TCP port 80 is commonly using HTTP and is sending the web server communication in the clear.

# %% [markdown]
# If someone's using HTTPS, then they're communicating through TCP port 443. And all of that traffic will be encrypted.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Simple Network Management Protocol (SNMP) ``udp/161``
# ***

# %% [markdown]
# If you're in charge of managing servers, switches, routers and other infrastructure devices, you may want to gather metrics from those devices.

# %% [markdown]
# One way to do this is to use SNMP. This is the Simple Network Management Protocol and it uses UDP port 161 to be able to query and receive data from these infrastructure devices.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# There are different versions of SNMP:

# %% [markdown]
# - v1 was the original that used a very set of structured tables and sent these requests and these responses across the network in a non-encrypted form.

# %% [markdown]
# - v2 of SNMP allowed us to do bulk transfers of data so we could request a lot of information and receive a lot of information very easily but all of that communication was sent in the clear.

# %% [markdown]
# - If we wanted an encrypted communication for our management protocol, then we want to use SNMP v3. This provides message integrity, authentication, and encryption so that nobody can see what you're requesting from that device, or what the response was from these infrastructure devices.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Remote Desktop Protocol (RDP) ``tcp/3389``
# ***

# %% [markdown]
# If you work in a help desk, or you do any type of remote administration of devices, then you're probably familiar with RDP or the remote desktop protocol.

# %% [markdown]
# This allows you to see the screen that is on a remote device and share the keyboard and the mouse on that device using TCP over port number 3389.

# %% [markdown]
# It's common to see Remote Desktop being used on many types of Windows operating systems and RDP allows you to either connect to the entire desktop that someone may be using, or to simply connect to an application that is available on that device.

# %% [markdown]
# There are also remote desktop clients available for other operating systems. So you can use your Mac OS or your Linux desktop to be able to remotely connect and administer these Windows devices using RDP.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Network Time Protocol (NTP) ``udp/123``
# ***

# %% [markdown]
# We have many different devices on our networks. We have our desktop computers, our laptop computers, servers, we have tablets and mobile devices.

# %% [markdown]
# All of those devices have a clock inside of them. They all know the time and the date. And they're able to determine what that is by using NTP or the network time protocol that communicates over UDP port 123.

# %% [markdown]
# It becomes critical to synchronise the clock across all of these different devices, not only to synchronise log information, but some of these devices must be well synced to be able to authenticate properly to each other. This means that everybody's going to know exactly what the proper date and the proper time is. And you as the administrator get to determine exactly the frequency that NTP will use to be able to provide this synchronisation.

# %% [markdown]
# This is a very accurate way of synchronising the clocks and on the local network you can get accuracy better than one millisecond across all of the devices using the Network Time Protocol.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Session Initiation Protocol (SIP) ``tcp/5060`` ``tcp/5061``
# ***

# %% [markdown]
# If you've used a voice over IP device then you've probably use SIP - this is the Session Initiation Protocol and it commonly uses TCP port number 5060 and TCP port 5061.

# %% [markdown]
# This is the protocol that's used for setting up calls for ringing the phone on the other side and for hanging up the call once the call is over.

# %% [markdown]
# It also extends your voice communication by adding video conferencing, instant messaging, file transfer, and many other applications using this Session Initiation Protocol.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Server Message Block (SMB) - Common Internet File System (CFS) ``tcp/445``
# ***

# %% [markdown]
# Microsoft uses SMB to transfer files between Windows devices - this is Server Message Block.

# %% [markdown]
# You may also hear this referred to as CIFS or common internet file system.

# %% [markdown]
# And it's what Windows uses to transfer files or to share printers between Windows systems.

# %% [markdown]
# SMB commonly uses TCP port 445 to be able to send SMB communication directly between devices using the IP protocol.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### [Email Receive] Post Office Protocol v3 (POP3) ``tcp/110``
# ***

# %% [markdown]
# Sending emails from your device uses Simple Mail Transfer Protocol (SMTP) ``tcp/25``.

# %% [markdown]
# But receiving emails uses a completely different set of protocols you may be using POP or you may be using IMAP to be able to authenticate and transfer email messages to your device.

# %% [markdown]
# POP3 is Post Office Protocol v3, and it uses TCP port 110 to be able to perform that function - considered to be a basic mail transfer functionality for most of our mobile devices we use today.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### [Email Receive] Internet Message Access Protocol v4 (IMAP4) ``tcp/143``
# ***

# %% [markdown]
# IMAP is Internet Message Access Protocol version four, and it uses TCP port 143.

# %% [markdown]
# This allows us to use multiple clients to access our inbox ao we can see exactly the same mailbox from our mobile device as we do from our desktop system.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Lightweight Directory Access Protocol (LDAP) ``tcp/389``
# ***

# %% [markdown]
# All of the users devices and printers are probably stored in a large database in your environment.

# %% [markdown]
# And it's usually accessed through a protocol such as LDAP.

# %% [markdown]
# LDAP is the Lightweight Directory Access Protocol and it uses TCP port 389 to allow your client to communicate to an LDAP server.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Lightweight Directory Access Protocol Secure (LDAPS) ``tcp/636``
# ***

# %% [markdown]
# There's also an encrypted form of LDAP called LDAPS and that stands for LDAP secure.

# %% [markdown]
# This uses SSL to be able to encrypt this LDAP communication and it uses TCP port 636 to be able to send that data.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### H.323 ``tcp/1720``
# ***

# %% [markdown]
# SIP is not the only voice over IP control protocol out there.

# %% [markdown]
# You may also use H 323 On your voice over IP devices and it uses TCP port 1720.

# %% [markdown]
# Similar to SIP, H.323 allows us to set up phone calls, be able to ring the phone on the other side and hang up the call when the call is over.

# %% [markdown]
# This is one of the earliest Voice over IP protocols and many Voice over IP applications will still use H.323 as its primary signalling protocol.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
