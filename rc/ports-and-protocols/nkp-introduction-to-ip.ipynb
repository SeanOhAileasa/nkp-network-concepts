# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-network-concepts/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Introduction to IP``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# <a id="topAdvancedNetworking"></a>
# ### [Introduction to IP](#networkConcepts)

# %% [markdown]
# - A Series of Moving Trucks <br/>
# 	- Road <br/>
# 		- Network Topology (Ethernet - DSL - Cable System) <br/>
# 	- Truck <br/>
# 		- Internet Protocol (IP) <br/>
# 			- OSI Layer 3 <br/>
# 				- Network <br/>
# 					- Routing Layer (IP Address - Router - Packet) <br/>
# 			- Ethernet Network <br/>
# 				- Ethernet Header <br/>
# 				- Ethernet Payload <br/>
# 					- IP Traffic <br/>
# 						- IP Payload <br/>
# 							- TCP (or UDP) [OSI Layer 4 - Transport] <br/>
# 								- TCP Payload <br/>
# 									- HTTP Data (ex. Web Browsing) <br/>
# 				- Ethernet Trailer <br/>
# 				![Image: Ethernet Network](https://github.com/SeanOhAileasa/SeanOhAileasa/blob/master/rc/nkp/ip-protocol-ethernet-network.png?raw=true) <br/>
# 	- Box <br/>
# 		- Encapsulated - Transmission Control Protocol (TCP) and User Datagram Protocol (UDP) <br/>
# 			- Multiplexing <br/>
# 				- Use Multiple Applications Simultaneously <br/>
# 		- Transmission Control Protocol (TCP) <br/>
# 		![Image: UDP](https://github.com/SeanOhAileasa/SeanOhAileasa/blob/master/rc/nkp/tcpiposi.png?raw=true) <br/>
# 			- Connection-oriented <br/>
# 				- Acknowledgement (``ACK``) <br/>
# 			- Reliable Delivery <br/>
# 				- Numbers the Data Sent <br/>
# 			- Flow Control <br/>
# 			![Image: TCP](https://github.com/SeanOhAileasa/SeanOhAileasa/blob/master/rc/nkp/tcp-data-ack.png?raw=true) <br/>
# 		- User Datagram Protocol (UDP) <br/>
# 			- Connectionless <br/>
# 			- Unreliable Delivery <br/>
# 				- No Error Recovery <br/>
# 				- No Reording of Data or Retransmissions <br/>
# 			- No Flow Control <br/>
# 				- Sender determines amount of Data Transmitted <br/>
# 				![Image: UDP](https://github.com/SeanOhAileasa/SeanOhAileasa/blob/master/rc/nkp/udp-data.png?raw=true) <br/>
# 		- Ports (Written on Box) <br/>
# 			- IPv4 Sockets <br/>
# 				- Information Sent <br/>
# 					- Server IP Address <br/>
# 						- Protocol (TCP or UDP) <br/>
# 							- Server Application Port Number <br/>
# 					- Client IP Address <br/>
# 						- Protocol (TCP or UDP) <br/>
# 							- Client Prot Number <br/>
# 			- Groups <br/>
# 				- Non-ephemeral (Non-Temporary - Permanent) <br/>
# 					- Server ("well known") <br/>
# 						- ``0 - 1023`` <br/>
# 				- Ephemeral (Temporary) <br/>
# 					- Client (Real-time) <br/>
# 						- ``1024 - 65535`` <br/>
# 			- TCP and UDP Ports Numbers <br/>
# 				- ``0 - 65535`` <br/>
# 					- No Conflict <br/>
# 	- Data <br/>
# 		- Application <br/>
# 			- TCP versus UDP <br/>
# 	- Internet Control Message Protocol (ICMP) <br/>
# 		- Administration <br/>
# 			- Carried by IP <br/>
# 				- Not used for Data Transfer <br/>
# 					- Text Messaging between Devices (ex. Time-To-Live Expired) <br/>

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkConcepts"></a>
# ***
# ### Introduction to IP (Internet Protocol)
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### A Series of Moving Vans
# ***

# %% [markdown]
# If you had an item that you needed to move between two addresses, it would be very common to use a moving truck, we would load the item into the back of the moving truck, drive it to the new address, and then unload the item.

# %% [markdown]
# It works exactly the same way for our networks, we would take some data, put it inside of a moving truck, move it across a network, and then unload it on the other end.

# %% [markdown]
# You can think of the network topology itself as being the road, this might be your Ethernet network or a DSL network, or one that's using a cable modem.

# %% [markdown]
# Inside of this truck, we have some data, which means the truck is going to be our Internet Protocol, it's going to be responsible for taking data from one end of the network and moving it to the other end of the network.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Inside of the moving truck is a box of data. This box of data is usually a TCP box of data or a UDP box of data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Inside of those boxes is the information that's very important to us. Usually it's application data, something that we can use to browse the internet or transfer a file.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# That means that we have a road (network topology) with a truck (Internet Protocol) inside of the road that has a box (TCP box of data or a UDP box of data) inside of the truck that has data (application data) inside of the box, and so on.

# %% [markdown]
# Everyone has a very specific job, the highway really doesn't care what type of truck is driving on it, we've chosen to put an IP truck on this particular highway, the truck doesn't really care what it's hauling in the back, there's simply a box that is in the back of the truck, all the truck is responsible for is getting to the address of its destination.

# %% [markdown]
# And the people that are moving this box in and out of the truck don't necessarily care what's inside of the boxes, as long as those boxes are able to be unloaded at the other end.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Internet Protocol IP
# ***

# %% [markdown]
# Let's start with an Ethernet network.

# %% [markdown]
# We have an Ethernet header at the beginning of some Ethernet data.

# %% [markdown]
# And we have an Ethernet trailer that is at the end of this Ethernet payload.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Inside of this Ethernet network we're transporting IP traffic.

# %% [markdown]
# And IP also has a payload associated with it.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We know that we have TCP or UDP data. In this case, it will be some TCP data that has some TCP payload.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# And a good example of TCP payload might be some HTTP data or some web browsing data that we might send through the network. So to move this web browsing traffic across the network, we need to package it up and encapsulate it within TCP, which then needs to be encapsulated within IP, which is then encapsulated within Ethernet.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Internet Protocol IP - Encapsulated - Transmission Control Protocol (TCP) and User Datagram Protocol (UDP)
# ***

# %% [markdown]
# Let's look into more detail about these TCP and UDP protocols that are encapsulated within IP.

# %% [markdown]
# There are two very different ways to move data from one side of the network to the other.

# %% [markdown]
# Some applications work better using the TCP protocol. Other applications work better if they're using the UDP protocol.

# %% [markdown]
# TCP and UDP operate at the OSI models layer four. When someone refers to a layer four protocol, they're almost always referring to either TCP or UDP.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### (TCP) and (UDP) - Multiplexing
# ***

# %% [markdown]
# One nice feature of TCP and UDP is that it allows us to use multiple applications at the same time across the network. This is multiplexing. And it's one of the advantages of using these protocols on an IP network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### (TCP) and (UDP) - Transmission Control Protocol (TCP)
# ***

# %% [markdown]
# TCP stands for transmission control protocol.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Transmission Control Protocol (TCP) - Connection-oriented
# ***

# %% [markdown]
# Called a connection oriented protocol. It's connection oriented because there's a formal connection made with a separate device on the network, data is transferred, and then that connection is formally terminated at the end of that communication. That means there's some additional overhead that takes place every time you need to send information via TCP.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Transmission Control Protocol (TCP) - Reliable
# ***

# %% [markdown]
# We also refer to TCP as a reliable mode of communication. This means that every time we send data to another device, we expect to receive an acknowledgment back from that device. You can think of this as being a return receipt, there is an evidence that delivery has been made. And that's why we call it a reliable delivery method. TCP also numbers the data that it's sending, so that if data is lost or data is received out of order, the device can either request some additional retransmissions of the lost data, or it can put all of the data back into its original order.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Transmission Control Protocol (TCP) - Flow Control
# ***

# %% [markdown]
# TCP also allows the receiving device to control the flow of traffic. If the receiving device would like to slow down or speed up the traffic flow, it can send a message to the sending device and control the flow of that communication.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### (TCP) and (UDP) - User Datagram Protocol (UDP)
# ***

# %% [markdown]
# UDP stands for User Datagram Protocol.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### User Datagram Protocol (UDP) - Connectionless
# ***

# %% [markdown]
# Unlike TCP, UDP does not have a formal call setup or a formal call breakdown process. It's what we call a connectionless protocol, because it simply starts sending data when Ever data is available, and it hopes the device on the other end is ready to receive.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### User Datagram Protocol (UDP) - Unreliable
# ***

# %% [markdown]
# You'll often hear UDP referred to as an unreliable form of delivery. This means that we don't get a return receipt or an acknowledgement from the other device. It's not that UDP works any better or worse than TCP to send this data, it's that we simply don't receive a verification that the data was indeed received. This also means that UDP does not have a way to recover from data that may have been lost, and it doesn't have a way to reorder data that may have been received out of order.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### User Datagram Protocol (UDP) - No Flow Control
# ***

# %% [markdown]
# Since the device that sending UDP data never receives any type of feedback from the receiving device, there's no way to provide any type of flow control the sending device is the one that will make the determination of how much data will be transmitted at any particular time.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Application - TCP versus UDP
# ***

# %% [markdown]
# Some applications commonly use TCP to communicate, and other applications commonly use UDP. The decision on which protocol to use is usually based on the way the application works. Some applications prefer to get an acknowledgment or return receipt that that information was received successfully. So those applications will use TCP.

# %% [markdown]
# Other applications may not have the same requirements, they're simply sending data. And they're not so concerned about whether that data got to the end station or not. In those cases, the application may choose UDP.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Speedy Delivery [Internet Protocol (IP)] - Ports
# ***

# %% [markdown]
# So now we know that our delivery truck is delivering from one address to another.

# %% [markdown]
# If it's the IP delivery truck, then it's delivering from one IP address to another IP address.

# %% [markdown]
# Just as every house has a physical address, all of your computers have their own IP address.

# %% [markdown]
# As our IP truck delivers this data to the destination IP address, the boxes are dropped off. But then where did those boxes go. If this is a traditional moving truck, then the box inside of the moving truck would probably have the name of a room, so the box may go to the bedroom or it may go to the living room.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# With IP, we don't use a room name. To describe where we're dropping off this box, we instead use a port number and this port number is instead written on the outside of the box. So instead of a bedroom, you may see the port 80. Instead of the living room, you may see port 443. And that way the box knows exactly where inside the house it needs to go.

# %% [markdown]
# We commonly associate different port numbers with different applications. So the port number 80 would be web traffic that is not encrypted and port 443 would be web traffic that was encrypted, we might be using port 25 to describe mail communication. And we might be using port 123 to describe a time synchronisation service. That way when the data arrives at this computer, it knows exactly which application it's destined for.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Internet Protocol (IP) - Ports - IPv4 Sockets
# ***

# %% [markdown]
# Let's summarise this list of information that's required to get data from one side of the network to the other using IP.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Internet Protocol (IP) - Ports - IPv4 Sockets -  Server
# ***

# %% [markdown]
# - We know that we have a server IP address that we're sending this to.

# %% [markdown]
# - We'll be using a TCP or UDP protocol.

# %% [markdown]
# - And then we'll also have a server application port number associated with this data.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Internet Protocol (IP) - Ports - IPv4 Sockets -  Client
# ***

# %% [markdown]
# - We also have a client IP address that is sending this data.

# %% [markdown]
# - It's using a TCP or UDP protocol.

# %% [markdown]
# - And we know there's a port number on the client side where this data will be sent back to.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Internet Protocol (IP) - Ports -  IPv4 Sockets - Groups
# ***

# %% [markdown]
# In IP networking we tend to describe port numbers as one of two different groups.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Internet Protocol (IP) - Ports - IPv4 Sockets - Groups - Non-ephemeral (Permanent)
# ***

# %% [markdown]
# One of these groups is a non ephemeral port group. Non-ephemeral means non temporary, this will be permanent port numbers that are used, and they're commonly used by applications or services that are running on a server. Those port numbers are usually defined as port 0 through 1023.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Internet Protocol (IP) - Ports  - IPv4 Sockets - Groups - Ephemeral (Temporary)
# ***

# %% [markdown]
# Ephemeral port numbers are temporary port numbers that the client usually decides to use randomly, as it's sending this information back to the server.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Internet Protocol (IP) - Ports  - IPv4 Sockets - Groups - Server (Non-ephemeral) - Client (Ephemeral)
# ***

# %% [markdown]
# - Server IP address would commonly use a non-ephemeral port.

# %% [markdown]
# - Client IP address is commonly going to use an ephemeral port number.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Internet Protocol (IP) - Ports - TCP and UDP Ports Numbers - 0 > 65535
# ***

# %% [markdown]
# This means the TCP port numbers can be between 0 and 65,535.

# %% [markdown]
# And UDP port numbers can be between zero and 65,535.

# %% [markdown]
# Although most servers or services will use permanent or non-ephemeral port numbers, this is not always the case, a server could choose to use any number it would like between 0 and 65,535.

# %% [markdown]
# These port numbers are used so that we can communicate back and forth from one device to another.

# %% [markdown]
# Changing a port number doesn't add any special kind of security. And you shouldn't use port numbers as a method to secure a particular application.

# %% [markdown]
# When you're accessing a server using this port number, you need to know what that number is. And that's why we often use this list of well known port numbers to describe certain applications. For instance, we know that HTTP commonly uses a well known TCP port number of 80. And we know that HTTPS commonly uses a well known TCP port number of 443.

# %% [markdown]
# TCP port numbers are different than UDP port numbers.

# %% [markdown]
# That means that one application could be using TCP port 80 to communicate and a completely different application could be using UDP port 80 to communicate.

# %% [markdown]
# And there's no conflict between either the TCP Port 80, or the UDP port 80.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Internet Protocol (IP) - Ports - Server
# ***

# %% [markdown]
# What you would commonly see on a server though, is not using the same port number for TCP or UDP.

# %% [markdown]
# Instead, we would use the well known port numbers to define certain applications that are running on that server.

# %% [markdown]
# For example, we have in this view, a client and we have a server, the client is IP address 10.0.0.1, and the server's IP address 10.0.0.2.

# %% [markdown]
# This server has three applications that are running on this device.

# %% [markdown]
# - One of the applications is a web server, and it's using TCP port 80. The well known TCP port number for web services.

# %% [markdown]
# - There's also a voice over IP (VoIP) server running on the server. And it's using UDP port 5004.

# %% [markdown]
# - And there's also an email server running on the server and it's using TCP port 143.

# %% [markdown]
# That means if we're going to send traffic from our client to our server it will send information via the TCP or UDP port numbers that are specified as the well known port numbers on that server.

# %% [markdown]
# - That means in order to use these applications, the client is going to send some TCP data over, for example, TCP port 80 to send the HTTP data.

# %% [markdown]
# - It will send information over UDP port 5004 to communicate this voice over IP data.

# %% [markdown]
# - And it will send email traffic over TCP port 143 to send the email data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# All of this information looks very similar as it's going across the network. But the server is going to look at those port numbers to determine exactly what application is going to get what data.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Internet Protocol (IP) - Ports - Packet
# ***

# %% [markdown]
# If we were to look into this IP packet with much more detail, we'd be able to see the source and destination IP addresses. We'd be able to see the source ports and the destination ports that are used. And we'd be able to see the application data that was included inside of the packet.

# %% [markdown]
# For example, we have a source IP address of 10.0.0.1 which is our client machine. And it's sending this packet to 10.0.0.2. That's our server, the client needs to be able to communicate over some source port number. So it randomly chooses a port number of 3000 so that the data will have somewhere to come back to once the server responds.

# %% [markdown]
# Then we have a TCP destination port 80. That means that we're going to the port 80 web services that are located on the server, and we're sending some HTTP data.

# %% [markdown]
# When the server sends the information back, it will simply switch the source and destination IP and the source and destination port numbers and send the information in the other direction.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We have similar traffic that's communicating between these two devices. This client randomly chose source port 7100 and it's sending it to the well known port number of 5004, which is used for voice over IP communication.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# And finally, we have some email data again, the client device chose a random port number of 4407 and it's sending it to the TCP destination port number of 143 to be able to send email information into that server.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This conversation using IP addresses and port numbers in data occurs every time you're sending IP information across the network. If you were to look at a protocol decode of all of this communication, you would very easily be able to break out the IP addresses the port numbers and all of the data so that you can examine the conversations that were occurring across the network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Internet Protocol (IP) - Internet Control Message Protocol (ICMP)
# ***

# %% [markdown]
# Sometimes the IP truck that we're sending from one IP address to another isn't really transporting any application data at all. It simply wants to check in on you.

# %% [markdown]
# One of the protocols that it uses for this is ICMP, this is the Internet Control Message Protocol.

# %% [markdown]
# You can think of it as text messaging between devices to check in and see how somebody might be doing.

# %% [markdown]
# This is yet another protocol that's carried by IP. And it's not one that you'll commonly see used for data transfer.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Internet Protocol (IP) - Internet Control Message Protocol (ICMP) - Administration
# ***

# %% [markdown]
# ICMP is commonly used for administrative use, you may want to check to see if a machine is operating or not. So you might send an ICMP request to see if that device is there. And if that device is there, it might send an ICMP response to let the original station know that it is alive and able to communicate on the network.

# %% [markdown]
# Devices can also use ICMP to let other devices on the network know when things aren't going so well. If you're sending information out to another network and a router realises that it's not able to communicate to that network, it may send back to your workstation an ICMP message saying that it's not able to communicate to that network or you may have traffic that is looping around the network and ultimately times out and the device that times out that traffic may send a message back to your workstation, letting you know that the Time To Live has expired.

# %% [markdown]
# All of these administrative functions are all using this ICMP protocol to be able to make this happen.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
