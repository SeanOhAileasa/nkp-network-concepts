# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-network-concepts/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Network Addressing``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# <a id="topAdvancedNetworking"></a>
# ### [Networking Addressing](#networkConcepts)

# %% [markdown]
# - [Binary Math](#networkConceptsBinaryMath) <br/><br/>
#     - [Binary to Decimal Conversion](#networkConceptsBinaryMathBinarytoDecimal) <br/><br/>
#     - [Decimal to Binary Conversion](#networkConceptsBinaryMathDecimaltoBinary) <br/><br/>
# - [More Bits then More Addresses](#networkConceptsBinaryMathMoreBitsthenMoreAddresses) <br/><br/>
#     - [Powers Of Two](#networkConceptsBinaryMathPowersOfTwo)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkConcepts"></a>
# ***
# ### Networking Addressing
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkConceptsBinaryMath"></a>
# ***
# ###### Binary Math
# ***

# %% [markdown]
# There are only two numbers to know when dealing with binary - ``0`` and ``1``.

# %% [markdown]
# The single digit is a bit in the binary system and putting eight bits together, refer to that as a byte (referred to as an octet to designate that there are indeed eight bits for every byte).

# %% [markdown]
# This binary to decimal conversion chart starts at the far right with the number 1, and each column is doubled all the way up to 128. This is the conversion chart to use to be able to convert from binary to decimal and back again.

# %% [markdown]
# The binary conversion chart created has eight separate columns and that’s because those eight columns group together to form a single byte or a single octet.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Could extend these columns so that they’re long enough to perform whatever binary calculation is needed.

# %% [markdown]
# But almost everything referring to binary calculations revolves around IP addressing, which means there will be groupings of 8 bits in a single byte.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkConceptsBinaryMathBinarytoDecimal"></a>
# ***
# ###### Binary to Decimal Conversion
# ***

# %% [markdown]
# Using this conversion chart to convert from a binary value to a decimal value.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The first thing to do is write out all of those individual bits in order and of course, trying to find what the decimal value of that might be.

# %% [markdown]
# Just above these bits, we’re going to write our conversion chart.

# %% [markdown]
# Start with 1, double it to 2, to 4, 8, all the way to 128.

# %% [markdown]
# Can see there is a separate value listed along with each individual bit that we’re trying to convert.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Next add all of these values based on the numbers in the conversion chart.

# %% [markdown]
# Every place there is is 0, we’re going to bring down a 0. But every place there is a 1, we’re going to bring down the value that’s associated with that place in our conversion chart.

# %% [markdown]
# Just above the 1 is the number 2 therefore bring down a 2.

# %% [markdown]
# Put all of these together, add them all up, will get a value of 2 decimal.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Got binary ``1 1 1 1 1 1 1 1`` so bringing all 1s down and putting all of the conversion chart numbers at the top.

# %% [markdown]
# This means pulling down every single 1 of those conversion chart numbers, add them all together to come up with ``255`` in decimal.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkConceptsBinaryMathDecimaltoBinary"></a>
# ***
# ###### Decimal to Binary Conversion
# ***

# %% [markdown]
# Reverse the process.

# %% [markdown]
# Start with a decimal value, and let’s determine what the binary equivalent is of that decimal value. Decimal ``154``.

# %% [markdown]
# Normally, would list out the binary numbers, but obviously, do not know what those are yet.

# %% [markdown]
# Will put the conversion chart right on the top of these unknown values.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# There is only one combination of 0s and 1s that would equal ``154`` in binary.

# %% [markdown]
# Step through each one of those decisions to see if we put a ``1`` or ``0`` in each one of those columns.

# %% [markdown]
# Start with the ``128`` that happens to be on the far left, and ask, is ``128`` less than or equal to the ``154`` decimal.

# %% [markdown]
# In this case, ``128`` is less than or equal to ``154``, quite a bit less therefore putting a 1 in that particular place, and we’ll bring down the ``128``.

# %% [markdown]
# Looking at the next value, which is a ``64``.

# %% [markdown]
# Adding ``128`` and ``64``, which happens to be ``192`` - ask is that less than or equal to ``154``? In this case, no.

# %% [markdown]
# It’s more than ``154`` so would put a ``0`` in that particular column.

# %% [markdown]
# Let’s perform the same question with the next column over, which is the 32. Is ``128`` plus ``32``, which is ``160``, less than or equal to ``154``?

# %% [markdown]
# That is not less than or equal to ``154`` so we put a ``0``.

# %% [markdown]
# The next values a ``16``.

# %% [markdown]
# Is ``128`` plus ``16``, which is ``144``, less than or equal to ``154``?

# %% [markdown]
# It is less than or equal to that value so putting a ``16`` down. Now, ``144`` is the number that we have so far, ``128`` plus ``16``.

# %% [markdown]
# So is ``144`` plus ``8``, our next column, less than or equal to ``154``?

# %% [markdown]
# It is, ``152`` is less than or equal to ``154``.

# %% [markdown]
# Bring down the value of ``8``.

# %% [markdown]
# Ask the same question of the next column, which is a ``4``.

# %% [markdown]
# Is ``152`` plus ``4`` less than or equal to ``154``?

# %% [markdown]
# It’s not. It’s more than ``154``.

# %% [markdown]
# Ask the same question in the ``2`` column.

# %% [markdown]
# Is ``152`` plus ``2``, which is ``154``, less than or equal to ``154``?

# %% [markdown]
# And it is equal to ``154``.

# %% [markdown]
# And now that we finally reached that value, all of the remaining bits will happen to be ``0``.

# %% [markdown]
# There’s only one column left, therefore putting a ``0`` in that column.

# %% [markdown]
# The binary representation of ``154`` decimal is ``1 0 0 1 1 0 1 0``.

# %%
128+16+8+2
# Out:
# 154

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkConceptsBinaryMathMoreBitsthenMoreAddresses"></a>
# ***
# ###### More Bits then More Addresses
# ***

# %% [markdown]
# If there are a fewer number of bits available for a calculation, then that means there are a fewer number of decimal representations of that value.

# %% [markdown]
# For example, if there are two bits available, the only possible options are ``0, 1, 2, and 3``.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If there’s three bits available, got ``0 through 7``.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If four bits are available, got ``0 through 15``, and so on.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkConceptsBinaryMathPowersOfTwo"></a>
# ***
# ###### Powers Of Two
# ***

# %% [markdown]
# So depending on how many binary bits will be available will determine what the range will be for the decimal equivalent.

# %% [markdown]
# Writing out the conversion chart above, really writing out the powers of ``2``.

# %%
2**1
# Out:
# 2

# %%
2**2
# Out:
# 4

# %%
2**3
# Out:
# 8

# %%
2**4
# Out:
# 16

# %% [markdown]
# A number of the calculations that converts to and from binary will use this particular chart.

# %% [markdown]
# Will use it for subnetting, other types of binary calculations, a will be a task that you become very familiar when networking.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
