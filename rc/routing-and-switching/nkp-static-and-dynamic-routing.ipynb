# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-network-concepts/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Static and Dynamic Routing``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# <a id="topAdvancedNetworking"></a>
# ### [Static and Dynamic Routing](#networkConcepts)

# %% [markdown]
# - Send IP Packets [Across Network] <br/>
# 	- Forwarding Decisions [Based on Destination IP Address] <br/>
# - Routing [Knows the network Step] <br/>
# 	- Packet asks for Directions [Every Hop Along the Way] <br/>
# 		- Directions (Steps) held in a Routing Table <br/>
# 	- Static Routing [Define List of Available Routes] <br/>
# 		- Administrator Define the Routes Manually <br/>
# 			- Advantages <br/>
# 				- Small/Simple Network [Easier if Statically Routed] <br/>
# 				- No Overhead from Routing Protocols <br/>
# 					- CPU <br/>
# 					- Memory <br/>
# 					- Bandwidth <br/>
# 				- Remote Sites [Sub Networks] <br/>
# 					- One way to send Data <br/>
# 				- Consider to be Secure  <br/>
# 					- No Routing Protocols Analysing how Traffic is Forwarded <br/>
# 			- Disadvanges <br/>
# 				- Difficult to Administer on Larger Networks <br/>
# 				- No Automatic Method to prevent Routing Loops <br/>
# 				- Link down (Network Change) requires Manual Reconfiguration <br/>
# 					- No Automatic Routing if Outage Occurs <br/>
# 		- Configuration [x2 Static Routes] <br/>
# 			- Table Update [Perspective of Particular Router (Router 1)] <br/>
# 				- Network Address (Sam) [Route] <br/>
# 					- ``10.10.20.0/24`` [Network of Jack] <br/>
# 						- Router Address [network Hop] <br/>
# 							- ``10.10.40.2/24`` [Hop to Jack] <br/>
# 					- ``10.10.30.0/24`` [Network of Teal'c] <br/>
# 						- Router Address [network Hop] <br/>
# 							- ``10.10.50.2/24`` [Hop to Teal'c] <br/>
# 				![Image: Static Routes](https://github.com/SeanOhAileasa/SeanOhAileasa/blob/master/rc/nkp/static-routes.png?raw=true) <br/>
# 	- Dynamic Routing <br/>
# 		- Routers Send Updates [(Almost) Real-time] <br/>
# 			- Advantages <br/>
# 				- No Manual Route Calculations or Management <br/>
# 				- New Routers Populated Automatically <br/>
# 				- Very Scalable <br/>
# 			- Disadvantages <br/>
# 				- Uses bandwidth to send Updates <br/>
# 					- Overhead Required [CPU - Memory - Bandwidth] <br/>
# 				- Requires Some Inital Configuration <br/>
# 		- Configuration [Automatic] <br/>
# 			- Remote Routers <br/>
# 				- Send Routing Update [All other Routers] <br/>
# 					- Receiving Router [Table (Routing) Automatically Updated] <br/>
# 						- Routing Information Protocol Version 2 (RIPv2) Update <br/>
# 	- Gateway of Last Resort <br/>
# 		- Default Route [Special Static Route] <br/>
# 			- Configured inside Router <br/>
# 				- No Match <br/>
# 					- Then Send this Way <br/>
# 			- Router make no Traffic Routing Decisions <br/>
# 				- Remote Site [Common] <br/>
# 					- Traffic [One-way] <br/>
# 						- Traffic Inside [Send Traffic Outside] <br/>
# 						- Traffic Outside [Send Traffic Inside] <br/>

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkConcepts"></a>
# ***
# ### Static and Dynamic Routing
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkConceptsStaticandDynamicRouting"></a>
# ***
# ###### Static and Dynamic Routing
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Routing
# ***

# %% [markdown]
# Watching a video on the internet, the packets that are containing the video content are hopping through a number of different routers to get to your workstation.

# %% [markdown]
# These routers make forwarding decisions based on what the destination IP addresses contained within those packets.

# %% [markdown]
# Each router only knows what the next step is to be able to get the packet along its way.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Routing - Steps [Routing Table]
# ***

# %% [markdown]
# There's a list of these next steps contained within every single router. And this is called the routing table.

# %% [markdown]
# Let's take the example of Sam that sending an IP packet to Jack. There are a number of different routers between both of these networks.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Sam sends the IP packet to her default router.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This router is going to look at the destination IP address that is contained within this packet and it's going to compare that IP address to a list of routes that are contained within its routing table.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# When it determines what the next step is going to be, it sends that packet out the next hop.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The same process occurs on the next router down the line, the routing table is referenced and the packet is sent out the appropriate interface.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# And finally on the last router, the same thing occurs and the packet is sent on to the interface that will get it closest to Jack's machine.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Routing - Steps [Routing Table] - Static Routing
# ***

# %% [markdown]
# One way to define this list of available routes in the routing table is for the network administrator to administratively add them to the routing table manually.

# %% [markdown]
# We call this static routing and the administrator of this router is the one that will determine what routing decisions are made and where traffic flows as it goes through this router.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Routing - Steps [Routing Table] - Static Routing - Small/Simple Network [Easier if Statically Routed - Not Worry about Dynamic Routing Protocols]
# ***

# %% [markdown]
# If you have a relatively small or simple network, it may be easier to have everything statically routed.

# %% [markdown]
# Don't have to worry about running any dynamic routing protocols.

# %% [markdown]
# And there's no additional overhead of routing protocols taking up CPU and bandwidth on the network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Routing - Steps [Routing Table] - Static Routing - Remote Sites [One way to send Data]
# ***

# %% [markdown]
# This is commonly done at remote sites where there's only one way to send data, so you would commonly add a single static route onto that router.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Routing - Steps [Routing Table] - Static Routing - Consider to be Secure [Dynamic Routing Protocols cannot make changes to the way Traffic is Forward]
# ***

# %% [markdown]
# You might also consider static routing to be more secure, because a dynamic routing protocol is not able to make changes to the way that traffic is forwarded through your router.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Routing - Steps [Routing Table] - Static Routing - Difficult to Administer
# ***

# %% [markdown]
# But static routes may be more difficult to administer, especially on networks that are larger and have many more routes associated with them.

# %% [markdown]
# It's very easy to make a mistake and accidentally configure a routing loop on a very large network like that.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Routing - Steps [Routing Table] - Static Routing - Link Down requires Manual Reconfiguration
# ***

# %% [markdown]
# If there's a change to the network, and one of those links happens to go down, you as the administrator would have to log into that router and manually reconfigure the static route.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Routing - Steps [Routing Table] - Static Routing - Update [i. Route Network Address ii. Next Hop Router Address]
# ***

# %% [markdown]
# When you're working with routing tables, you have to interpret that routing table from the perspective of that individual router.

# %% [markdown]
# Let's look at this network configuration where we have Sam, Jack and Teal'c on this particular network configuration and they're separated from each other by three individual routers.

# %% [markdown]
#  ![image.png](attachment:image.png)

# %% [markdown]
# Let's look at only router one for this particular static routing example, we know that Router 1 is directly connected to the ``10.10.10.0/24`` network - got a direct connection to the ``10.10.40.0/24`` network - directly connected to the ``10.10.50.0/24`` network.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If Sam needs to send any traffic to Jack, we're going to need a route inside of router one that will allow that communication.

# %% [markdown]
# So we need to add a route to ``10.10.20.0/24`` and we'll tell Router 1, if you need to get to that network, you need to send all of that traffic to ``10.10.40.2``.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Let's add another static route that will allow us to send traffic down to Teal'c network.

# %% [markdown]
# We'll add another routing entry for ``10.10.30.0`` because that's the network that Teal'c is on.

# %% [markdown]
# And we'll say to get to that network, we need to send all of that traffic to ``10.10.50.2``, which is the interface on Router 3.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Routing - Steps [Routing Table] - Dynamic Routing
# ***

# %% [markdown]
# That was a good bit of configuration just to add two additional static routes into this router.

# %% [markdown]
# Would it be nice if this entire process was handled automatically and you wouldn't have to add any routes at all. You can do that by using dynamic routing.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Routing - Steps [Routing Table] - Dynamic Routing - Routers send Updates
# ***

# %% [markdown]
# This is when the routers will send updates to each other and if there's any changes to the network, it will update those routing tables in just a matter of seconds so that all of the routers know exactly how to send traffic across the network.

# %% [markdown]
# This means that we don't have to perform any manual configurations of the routes.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Routing - Steps [Routing Table] - Dynamic Routing - Routers send Updates - New Routers added Automatically
# ***

# %% [markdown]
# If there are any new routes that suddenly appear they will automatically be added to all of the other routers in our environment and it will be able to scale as we add more and more routers to our infrastructure.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Routing - Steps [Routing Table] - Dynamic Routing - Routers send Updates - Uses bandwidth to send Updates
# ***

# %% [markdown]
# Dynamic routing does have some disadvantages. It's using some bandwidth to be able to send these updates between the routers and there's memory and CPU that's used inside of the router to store this information.

# %% [markdown]
# There's also some initial configuration that has to take place to be able to send these dynamic routes between all of the different routers.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Routing - Steps [Routing Table] - Dynamic Routing - Routers send Updates - RIPv2 Update
# ***

# %% [markdown]
# Here's the exact same network we still have Sam and Jack and Teal'c - we're still looking at the routes from the perspective of Router 1, we have all of the connected routes that are automatically added to every routing table. But now we need to have the routes added so that we can communicate to the ``10.10.20.0`` network and the ``10.1030.0`` network.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# With a dynamic routing protocol, the remote routers will send routing updates to all of the other routers on the network.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# And when those router updates are received, the information is automatically added to the routing table.

# %% [markdown]
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# Same thing will occur as the routing update comes from Router 3 to Router 1.

# %% [markdown]
# Router 1 will automatically update its routing table automatically using this dynamic routing protocol.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Routing - Default Route [Static Routing]
# ***

# %% [markdown]
# There's a special kind of static route called a default route.

# %% [markdown]
# This is a route that you configure inside the router that says if nothing else, matches inside of our routing table send the traffic this way.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Routing - Default Route [Static Routing] - Gateway of Last Resort
# ***

# %% [markdown]
# You might also see this referred to as the gateway of last resort.

# %% [markdown]
# A default route is a very common configuration to put at something like a remote site where there's only one way to send traffic out and one way to send traffic in. This means the router really doesn't have to make any decision about forwarding traffic. If traffic's coming from the inside, it sends the traffic to the outside. If traffic is coming from the outside, it sends the traffic into the inside and that's exactly the scenario that we would commonly use a default route with.

# %% [markdown]
# If you have a network that has a number of internal routes and a lot of external routes, this could also simplify the process of building your routing table.

# %% [markdown]
# Instead of listing out all of the external routes, you could simply add a default route and send all of the traffic external whenever it didn't match anything on the inside.

# %% [markdown]
# The network diagram we use before is a very good example of how a default route may work.

# %% [markdown]
# We might want to look at Jack's network where there's only one way out and one way in.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In this particular scenario, it would be perfect to add a default route into Router 2, that said if there's any traffic coming inbound that needs to go out, simply send it down to the next hop at ``10.10.40.1``.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If Jack does send traffic to that router, the router simply looks at the default route and sends the traffic on its way.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
