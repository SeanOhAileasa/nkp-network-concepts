# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-network-concepts/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Spanning Tree Protocol``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# <a id="topAdvancedNetworking"></a>
# ### [Spanning Tree Protocol](#networkConcepts)

# %% [markdown]
# - Ethernet Switches [Connect via Single Cable] <br/>
# 	- Second Cable [Creates Loop between both Switches] <br/>
# 		- No Counting Mechanism at the MAC Layer [Until Cable Pulled out of a Switch] <br/>
# 			- Sending Traffic back and forth Forever <br/>
# 				- Break Network <br/>
# - Loop Protection <br/>
# 	- Spanning Tree Protocol (STP) <br/>
# 		- Standards <br/>
# 			- ``802.1D`` <br/>
# 		- Prevent Loops (Bridged [Switched] Networks) <br/>
# 			- MAC Layer <br/>
# 		- Port Configured to use STP <br/>
# 			- States <br/>
# 				- Blocking <br/>
# 					- ``!=`` Forwarding to Prevent Loop <br/>
# 				- Listening <br/>
# 					- ``!=`` Forwarding & Cleaning the MAC Table <br/>
# 				- Learning <br/>
# 					- ``!=`` Forwarding & Adding to the MAC Table <br/>
# 				- Forwarding <br/>
# 					- Data Passes Through (Fully Operational) <br/>
# 				- Disabled <br/>
# 					- Administrator Turns Off Port <br/>
# 		- Configured (Automatically - May take Longer Path Traversal) Interfaces <br/>
# 			- Root Switch [x1 on any STP Network] <br/>
# 				- Root Port (RP) <br/>
# 					- Other Switches [Interface closest to Root Switch designated Root Port] <br/>
# 						- Allows Traffic to Traverse Particular Interface <br/>
# 							- Other Interface <br/>
# 								- Traffic Allowed to Traverse <br/>
# 									- Designated Port (DP) <br/>
# 							- Port STP Disabled [Prevent Loop] <br/>
# 								- Blocked Port (BP) <br/>
# 								![Image: STP Network](https://github.com/SeanOhAileasa/SeanOhAileasa/blob/master/rc/nkp/stp-network.png?raw=true) <br/>
# 		- Switch Fails or Link Disconnected <br/>
# 			- Converge Network & Restructure Devices [Reconfigure through STP] <br/>
# 				- Maintains Loop Free Environment <br/>
# 					- Convergence Process [Network Back] <br/>
# 						- ``30`` to ``50`` Seconds <br/>
# 				![Image: Switch or Link Fails then STP Reconfigures](https://github.com/SeanOhAileasa/SeanOhAileasa/blob/master/rc/nkp/link-broken-stp-reconfigure.png?raw=true) <br/>
# 	- STP Updated <br/>
# 		- Rapid Spanning Tree Protocol (RSTP) <br/>
# 			- Standard <br/>
# 				- ``802.1w`` <br/>
# 					- Convergence Process [Network Back] <br/>
# 						- 	``6`` Seconds <br/>
# 					- Backwards-compatible with ``802.1D`` STP [Mix in Network] <br/>
# 					- Update not Wholesale Change <br/>

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkConcepts"></a>
# ***
# ### Spanning Tree Protocol
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkConceptsSpanningTreeProtocol"></a>
# ***
# ###### Spanning Tree Protocol
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Ethernet Switches [Single Cable]
# ***

# %% [markdown]
# Ethernet switches are fantastic devices to use for networking and to connect two switches together.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Ethernet Switches [Single Cable] - Second Cable [Loop]
# ***

# %% [markdown]
# You would commonly put a cable between both of those switches, however, you'll run into a problem if you put a second cable between both of those switches and effectively create a loop between both of those switches.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Loop Protection
# ***

# %% [markdown]
# There's no method to be able to count how many times a frame might go between devices with Ethernet because there is no counting mechanism at that media access control layer, those frames will loop around that particular network until you pull one of those cables out of one of those switches.

# %% [markdown]
# This loop will quickly bring a network to its knees, as more data is put onto the network, it's added to the loop and very quickly, you're able to overwhelm the capabilities of those switches.

# %% [markdown]
# This type of problem occurs almost immediately, so if you happen to notice there's an issue, it's very easy to rewind everything you might have done in the last few minutes and disconnect any of those cables that you may have created redundantly between those switches.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Loop Protection - Spanning Tree Protocol (STP) ``802.1d`` [MAC Layer]
# ***

# %% [markdown]
# Fortunately, there's a way to prevent any of this from happening, even if you accidentally create a loop between two switches.

# %% [markdown]
# This is using something called Spanning Tree Protocol (STP) - an IEEE standard ``802.1D`` and it's designed specifically to prevent loops at this media access control layer.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Loop Protection - Spanning Tree Protocol (STP) - Port States - [Mode] Blocking
# ***

# %% [markdown]
# If a port on a switch has been configured to use Spanning Tree Protocol, there are a certain set of states that this particular port might be in.

# %% [markdown]
# One of these might be a blocking state, the switch may have decided that if it was allowing traffic to go through this particular interface that a loop would occur on the network and it's decided through Spanning Tree Protocol to administratively block any traffic from going through that port.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Loop Protection - Spanning Tree Protocol (STP) - Port States - [Mode] Listening
# ***

# %% [markdown]
# While spanning tree is converging, it may go into a listening state where an interface isn't passing traffic, but it is listening to find out what other Spanning Tree Protocol devices might be on the network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Loop Protection - Spanning Tree Protocol (STP) - Port States - [Mode] Learning
# ***

# %% [markdown]
# Once it begins hearing the other devices on the network it will start adding them to a spanning tree table and this is called a learning mode for that particular port.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Loop Protection - Spanning Tree Protocol (STP) - Port States - [Mode] Forwarding
# ***

# %% [markdown]
# Once traffic is allowed through that port, it goes into a forwarding mode which is a fully operational mode to allow traffic to communicate using Spanning Tree Protocol and you as the administrator could decide to completely disallow any traffic from ever going across that interface by administratively disabling the port.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Loop Protection - Spanning Tree Protocol (STP) - Automatically Configured Interfaces
# ***

# %% [markdown]
# Here's an example network that using the spanning tree protocol.

# %% [markdown]
# If the spanning tree protocol was not enabled on this network, you would have a loop, as traffic was able to move between any of these networks at any time.

# %% [markdown]
# There's three types of interfaces that are configured automatically through Spanning Tree Protocol:
#
#
# i. Root Port
#
#
# ii. Designated Port
#
#
# iii. Blocked Port

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Loop Protection - Spanning Tree Protocol (STP) - Automatically Configured Interfaces - Root Port [Root Switch]
# ***

# %% [markdown]
# The root port on this network spanning tree is defined by one switch as the root switch, there's only one root switch on any spanning tree network.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# On all of the other switches, one of those interfaces will be the one that is closest to the root switch, and that is the one designated as the root port.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The root port will allow traffic to traverse this particular interface.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Loop Protection - Spanning Tree Protocol (STP) - Automatically Configured Interfaces - Designated Port
# ***

# %% [markdown]
# The other interfaces that are on this switch that traffic is allowed to traverse are called the designated ports.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Loop Protection - Spanning Tree Protocol (STP) - Automatically Configured Interfaces - Blocked Port
# ***

# %% [markdown]
# If there's any port on any of these switches, that spanning tree has decided to disable to prevent a loop, it will designate that as a blocked port.

# %% [markdown]
# Because of this configuration that has been built automatically by spanning tree, we can communicate between all of these different networks without the worry of having any loops on the network.

# %% [markdown]
# This does mean though that some of the communication may take a longer path than we might expect.

# %% [markdown]
# For example, to go from Network Y to Network C, we can't go through bridge 11 because spanning tree has blocked one of the ports between those two networks.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Instead Network Y would have to go to Network A, then the Network M, then the Network J and then the Network C, to finally complete that communication.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Loop Protection - Spanning Tree Protocol (STP) - Converge Network & Restructure Devices [Switch Fails or Link Disconnected]
# ***

# %% [markdown]
# Very often on a network of this size we might have some type of change - one of the switches may fail or one of the links between switches may become disconnected. When that occurs spanning tree has to converge the network and restructure which devices are connected through spanning tree.

# %% [markdown]
# For example, let's say that this connection between Network A and Bridge 6 is severed.

# %% [markdown]
# Normally Network A would be able to use that connection to go to other parts of the network, but now that connection is no longer available.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Spanning tree will reconfigure itself now by sending messages between all of the different bridges and it will reconfigure the links so that this communication can now exist through other parts of the network while still maintaining a loop free environment.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Loop Protection - Rapid Spanning Tree Protocol (RSTP) ``802.1w``
# ***

# %% [markdown]
# One of the newer standards of Spanning Tree Protocol is rapid Spanning Tree Protocol or RSTP.

# %% [markdown]
# You may also hear this referred to as ``802.1w``.

# %% [markdown]
# Rapid Spanning Tree Protocol was created because the convergence process with the original Spanning Tree Protocol can take anywhere from 30 to 50 seconds and on our modern networks 30 to 50 seconds is a very long amount of time.

# %% [markdown]
# With rapid Spanning Tree Protocol that convergence process takes only six seconds to bring the network back up and running.

# %% [markdown]
# Fortunately, rapid Spanning Tree Protocol and the original Spanning Tree Protocol can both coexist on the same network. So if you have older equipment, you're still able to take advantage of Rapid Spanning Tree Protocol on your newer equipment and be able to have both of those coexist simultaneously.

# %% [markdown]
# Another advantage of rapid Spanning Tree Protocol is that if you already know how spanning tree protocol works, there are a lot of differences between spanning tree and rapid spanning tree making it very easy for network administrators to easily update to the latest version of rapid Spanning Tree Protocol.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
