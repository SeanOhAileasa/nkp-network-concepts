# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-network-concepts/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Broadcast Domains and Collision Domains``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# <a id="topAdvancedNetworking"></a>
# ### [Broadcast Domains and Collision Domains](#networkConcepts)

# %% [markdown]
# - Collision Domains [Half-duplex Networks] <br/>
# 	- Collision [Hub] <br/>
# 		- Normal Process (Network Communication) <br/>
# 	- CSMA/CD <br/>
# 		- Carrier Sense Multiple Access (CSMA) <br/>
# 			- Network Stations Listening <br/>
# 				- Determine if able to Communication <br/>
# 		- Collison Detection (CD) <br/>
# 			- Network Stations recognise Collision Occurred <br/>
# 				- Clear Network [Sending Jam Signal] <br/>
# 					- Retransmit <br/>
# 	- Historial Footnote [One Big Segment] <br/>
# 		- Coax Network <br/>
# 			- Stations Connected on same Cable <br/>
# 		- Ethernet Hub <br/>
# 			- Stations Connected to Central Device <br/>
# 	- Segment different Networks (Segment out Collision Domains) <br/>
# 		- Switch (or Bridge) <br/>
# 			- Each side of Switch a different Collision Domain <br/>
# 	- Modern Footnote <br/>
# 		- Switch (Collision Domains Removed) <br/>
# 			- Full-duplex <br/>
# 				- Stations can Send / Receive Simultaneously <br/>
# 					- No Concern of a Collision <br/>
# 					![Image: Collision Domains](https://github.com/SeanOhAileasa/SeanOhAileasa/blob/master/rc/nkp/collision-domains.png?raw=true) <br/>
# - Broadcast Frames (Different to Collisions) [Necessary Evil] <br/>
# 	- Send Broadcast Address <br/>
# 		- Spread the Word (All must Know) <br/>
# 			- Address Resolution Protocol (ARP) Requests <br/>
# 			- Operating System Notifications <br/>
# 			- Some Dynamic Routing Protocols <br/>
# 				- Advertise Available Network Routes <br/>
# - Broadcast Domains <br/>
# 	- Switch Network [Switch / Bridge] <br/>
# 		- All See Broadcast <br/>
# 	- Router <br/>
# 		- Separating Network <br/>
# 			- Block Broadcast <br/>
# 	- Segment Network
# 		- Segmenting Broadcasts [Particular Broadcast Domain] <br/>
# 		![Image: Broadcast Domains](https://github.com/SeanOhAileasa/SeanOhAileasa/blob/master/rc/nkp/broadcast-domains.png?raw=true) <br/>

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkConcepts"></a>
# ***
# ### Broadcast Domains and Collision Domains
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkConceptsBroadcastDomainsandCollisionDomains"></a>
# ***
# ###### Broadcast Domains and Collision Domains
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Collison Domains
# ***

# %% [markdown]
# When half-duplex ethernet networks were all the rage, we had to be very concerned about collision domains.

# %% [markdown]
# These days, it's hard to find a collision domain because we use full-duplex ethernet, and the term collision is a bit misleading.

# %% [markdown]
# If you're driving a car, a collision is something you never want to occur. But on a half-duplex ethernet network, a collision is simply the normal process that occurs when people are trying to communicate on the network and it's perfectly expected to see collisions occur on a half-duplex ethernet network.

# %% [markdown]
# The days of using a hub with a half-duplex ethernet network is a lot like talking on a conference call where everybody can hear everyone else, you have to only allow one person to communicate on the conference call at a time, or everything becomes jumbled and nobody can make out any information.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Collison Domains - Carrier Sense Multiple Access (CSMA)
# ***

# %% [markdown]
# The CSMA of CSMA/CD was this process of stations listening on the network to determine if they were able to communicate.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Collison Domains - Carrier Sense Multiple Access/Collison Detection (CSMA/CD)
# ***

# %% [markdown]
# The CD part of the CSMA/CD was the station's able to recognise that a collision occurred, clearing out the network with the jam signal and try to retransmit again.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Collison Domains - Coax Network
# ***

# %% [markdown]
# We used to connect Ethernet networks together with coax, everyone was literally on the same cable, so of course, every station heard all of the other stations communicating on the network.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Collison Domains - Ethernet Hub
# ***

# %% [markdown]
# With Ethernet hubs, this changed the way the network looked because we were sending all of our wires down to one central device.

# %% [markdown]
# But the devices still all heard each other communicating, very similar to the way it worked on a coax network.

# %% [markdown]
# With this hub in the middle, two stations could still communicate at the same time and a collision would occur.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Collison Domains - Switch (Segment)
# ***

# %% [markdown]
# The only way to segment out these different networks or segment out these collision domains was to put a switch or bridge in the middle of the communication.

# %% [markdown]
# With a switch in the middle, everyone on one side of the network would be one collision domain, and everyone on the other side of the network would be a different collision domain.

# %% [markdown]
# This meant as our networks grew larger and larger, we could continue to segment them to limit the impact that collisions would have on a particular group of devices.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Collison Domains - Switch - Full-duplex
# ***

# %% [markdown]
# And on today's modern networks, we've effectively removed collision domains by adding a switch into the middle of the network and enabling full-duplex communication between all of these devices.

# %% [markdown]
# That means that everyone is able to both send and receive simultaneously without any concern that a collision might occur.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Broadcast Frames
# ***

# %% [markdown]
# Broadcast frames are completely different than dealing with collisions.

# %% [markdown]
# Broadcast frames are things that are a necessary evil on a lot of our networks. For example, there are some things that a device may want to send out to all of the other devices on the network - it does that by sending this as a broadcast address this might be ARP requests, the operating system may be notifying other devices on the network of operating system functions and some dynamic routing protocols will use broadcast domains to advertise the routes that are available on the network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Broadcast Domains - Switch
# ***

# %% [markdown]
# With broadcast domains, everyone who is on a switch network will be able to see that broadcast as it's sent across the network.

# %% [markdown]
# A bridge or a switch will simply pass these broadcasts to every other interface on that switch.

# %% [markdown]
# The only way to block a broadcast is to put a router on the network and the broadcast will not go through a routed connection.

# %% [markdown]
# This is a good reason to keep networks a convenient size, the larger these networks become, the more broadcasts will appear on the network. If you segment the network, then you're probably going to be segmenting the amount of broadcasts that would occur on a particular broadcast domain.

# %% [markdown]
# Here's our modern full-duplex switch network and every device that is connected to that switch network is on the same broadcast domain. If a device sends a broadcast frame, it will be redirected to all of the other devices that happen to be on this switch network.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Broadcast Domains - Router
# ***

# %% [markdown]
# The way that you would limit the broadcast is to then separate the network with a router in the middle.

# %% [markdown]
# That means that any devices sending a broadcast on the LHS of the router will only be seen by these devices and any device sending a broadcast on the RHS of the router will only be seen by these devices.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
