# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-network-concepts/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Network Concepts``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# <a id="topAdvancedNetworking"></a>
# ### [Networking Concepts](#networkConcepts)

# %% [markdown]
# - [Configuring DHCP](#ConfiguringDHCP) <br/><br/>
#     - [Scope Properties](#ConfiguringDHCPScopeProperties) <br/><br/>
#     - [DHCP Pools](#ConfiguringDHCPScopeDHCPPools) <br/><br/>
# - [DHCP Server](#ConfiguringDHCPWindowsServer) <br/><br/>
#     - [Windows](#ConfiguringDHCPWindowsServer) <br/><br/>
# - [DHCP Address Allocation](#ConfiguringDHCPWindowsServerDHCPAddressAllocationDynamicAllocation) <br/><br/>
#     - [Dynamic](#ConfiguringDHCPWindowsServerDHCPAddressAllocationDynamicAllocationd) <br/><br/>
#     - [Automatic](#ConfiguringDHCPWindowsServerDHCPAddressAllocationDynamicAllocationa) <br/><br/>
#     - [Static](#ConfiguringDHCPWindowsServerDHCPAddressAllocationDynamicAllocations) | [Static DHCP Assignment](#ConfiguringDHCPWindowsServerDHCPAddressAllocationDynamicAllocations) | [Static DHCP](#ConfiguringDHCPWindowsServerDHCPAddressAllocationDynamicAllocations) | [Address Reservation](#ConfiguringDHCPWindowsServerDHCPAddressAllocationDynamicAllocations) | [IP Reservation](#ConfiguringDHCPWindowsServerDHCPAddressAllocationDynamicAllocations) <br/><br/>
#         - [Wireless Router](#WirelessRouterAddressReservation) <br/><br/>
#             - [Address Reservation](#WirelessRouterAddressReservation) <br/><br/>
# - [DHCP Leases](#DHCPLeases) <br/><br/>
#     - [Allocation](#DHCPLeasesAllocation) <br/><br/>
#     - [Reallocation](#DHCPLeasesReallocation) <br/><br/>
#     - [Reallocation](#DHCPLeasesReallocation) <br/><br/>
#     - [Manually Release](#DHCPLeasesManuallyRelease) <br/><br/>
# - [DHCP Renewal](#DHCPRenewal) <br/><br/>
#     - [T1 Timer](#DHCPLeasesReallocation) <br/><br/>
#     - [T2 Timer](#DHCPLeasesReallocation) <br/><br/>
# - [Lease Process](#LeaseProcess)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkConcepts"></a>
# ***
# ### Networking Concepts
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="ConfiguringDHCP"></a>
# ***
# ###### Configuring DHCP
# ***

# %% [markdown]
# Configuring a DHCP server, with configuring a scope inside of that server.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="ConfiguringDHCPScopeProperties"></a>
# ***
# ###### Scope Properties
# ***

# %% [markdown]
# This is usually a list of the IP addresses that will be available for devices on a particular IP subnet.

# %% [markdown]
# This may also include subnet mask information.

# %% [markdown]
# You’ll specify how long these IP addresses will be least for, and you may also include other IP configurations, such as a DNS server, a default gateway, WIN servers, and other IP address configuration details.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="ConfiguringDHCPScopeDHCPPools"></a>
# ***
# ###### DHCP Pools
# ***

# %% [markdown]
# It’s also common to provide a grouping of IP addresses that will be leased out by the DHCP server.

# %% [markdown]
# We call this a DHCP pool, and there’s usually a separate pool for each subnet that will be serviced by this DHCP server.

# %% [markdown]
# It’s usually a large contiguous range of IP addresses, but of course, certain IP addresses can be excluded from this pool.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="ConfiguringDHCPWindowsServer"></a>
# ***
# ###### DHCP Server [Windows Server]
# ***

# %% [markdown]
# Here’s a DHCP server that’s running on a Windows Server.

# %% [markdown]
# This one is providing DHCP services for the ``sg-1.sgc.local`` domain, and these are the parameters for IPv4 IP addresses in my DHCP server.

# %% [markdown]
# Created a single scope for this particular server, which is servicing ``165.245.44.0``.

# %% [markdown]
# The scope includes an address pool, so we have a list of available IP addresses.

# %% [markdown]
# We have address leases, so we can see exactly what devices have been provided an IP address.

# %% [markdown]
# I can provide reservation, so I can associate a single IP address with a MAC address and automatically configure that using DHCP.

# %% [markdown]
# Then I have a section for scope options to provide additional details for these IP leases.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="ConfiguringDHCPWindowsServerDHCPAddressAllocationDynamicAllocation"></a>
# ***
# ###### DHCP Address Allocation
# ***

# %% [markdown]
# There are many different ways For a DHCP server to allocate IP addresses to these remote devices.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="ConfiguringDHCPWindowsServerDHCPAddressAllocationDynamicAllocationd"></a>
# ***
# ###### Dynamic Allocation
# ***

# %% [markdown]
# One is through dynamic allocation.

# %% [markdown]
# There’s a large IP address pool.

# %% [markdown]
# As devices come onto the network, they are provided an IP address.

# %% [markdown]
# If a device leaves the network and that particular lease expires, then that IP address is put back into the pool.

# %% [markdown]
# When that device comes back onto the network, it may or may not be provided the same IP address.

# %% [markdown]
# One is simply chosen from the pool again and provided to that particular device.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="ConfiguringDHCPWindowsServerDHCPAddressAllocationDynamicAllocationa"></a>
# ***
# ###### Automatic Allocation
# ***

# %% [markdown]
# With an automatic allocation, a device that receives an IP address will always have that IP address associated with that device.

# %% [markdown]
# The DHCP server is going to keep a list of all of the MAC addresses, and it’s going to permanently associate an IP address to that MAC address.

# %% [markdown]
# That means if you were to leave the network and come back a month later, you’ll be assigned exactly the same IP address that you received a month ago.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="ConfiguringDHCPWindowsServerDHCPAddressAllocationDynamicAllocations"></a>
# ***
# ###### Static Allocation [Static DHCP Assignment - Static DHCP - Address Reservation - IP Reservation]
# ***

# %% [markdown]
# You can also use DHCP to statically configure an IP address on a device.

# %% [markdown]
# You may have a server or a router or a switch that you would like to have the IP address configured automatically when those devices start up, but you want those devices to always have exactly the same IP address.

# %% [markdown]
# You can do that by associating the MAC address of that device with the IP address that you would like it to have.

# %% [markdown]
# You might see this referred to as a Static DHCP Assignment, a Static DHCP, an Address reservation, or an IP Reservation.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="WirelessRouterAddressReservation"></a>
# ***
# ###### Wireless Router [Address Reservation]
# ***

# %% [markdown]
# Have a DHCP server running on my wireless router, and it also provides me with static allocations.

# %% [markdown]
# It calls these address reservations, and you can see that I can add an IP address, I can even put in the name of a device, and then I can specify the MAC address of that device.

# %% [markdown]
# So if this DHCP server sees this MAC address on the network, it will provide a DHCP address that’s specified in my address reservations, rather than pulling in a address from the available pool.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="DHCPLeases"></a>
# ***
# ###### DHCP Leases
# ***

# %% [markdown]
# The IP addresses we’re assigned with DHCP are only temporary.

# %% [markdown]
# There is an existing lease time that is associated with that IP address and the moment we receive that IP address, the lease begins counting down.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="DHCPLeasesAllocation"></a>
# ***
# ###### Allocation
# ***

# %% [markdown]
# There is an allocation then that’s initially made by the DHCP server.

# %% [markdown]
# Your device is assigned a lease time, and this configuration for the lease time is usually made on the DHCP server configuration.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="DHCPLeasesReallocation"></a>
# ***
# ###### Reallocation
# ***

# %% [markdown]
# If you were to reboot your computer, a re-allocation process tries to use the same IP address that it had originally if it’s still available, and if it is, it’s provided to your computer and the lease timer is reset.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="DHCPLeasesManuallyRelease"></a>
# ***
# ###### Manually Release
# ***

# %% [markdown]
# Of course, you don’t have to wait for the timer to expire to give up that IP address.

# %% [markdown]
# You can manually release the IP address on your device, and that IP address is now available to others in the pool.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="DHCPRenewal"></a>
# ***
# ###### DHCP Renewal
# ***

# %% [markdown]
# When we are first assigned an IP address, there’s a lease timer associated with this.

# %% [markdown]
# There’s actually two timers that will start counting down.

# %% [markdown]
# The first one is a ``T1 Timer``.

# %% [markdown]
# This is when your device will check in to be able to renew this IP address, and the T1 timer is 50% of the lease time by default.

# %% [markdown]
# There’s another timer that is the ``T2 timer.

# %% [markdown]
# If the original DHCP server is no longer available on the network, it will try rebinding this IP address with some other DHCP server that might be available.

# %% [markdown]
# The T2 timer is 87.5% of the lease time or ``7/8`` of the lease time.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="LeaseProcess"></a>
# ***
# ###### Lease Process
# ***

# %% [markdown]
# On a laptop that has received an IP address or the lease time is eight days.

# %% [markdown]
# Do the math, we know that it will try to perform a renewal timer after four days, because the T1 timer, by default, is 50%.

# %% [markdown]
# It will try rebinding or use the T2 timer after seven days.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So if four days goes by and into the fifth day, this device will try to check back in and renew the T1 timer.

# %% [markdown]
# Can see here that it has updated itself on that original DHCP server, and now we start the timer back again.

# %% [markdown]
# Now that DHCP server suddenly becomes unavailable, and we go past the 50% mark.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Now when we finally get to the 87.5% or seven days into this particular lease, it will try to rebind itself with some remaining DHCP server on the network, and if that’s successful the process is reset and the timer begins counting forward again.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
