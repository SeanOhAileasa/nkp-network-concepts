# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-network-concepts/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Network Concepts``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# <a id="topAdvancedNetworking"></a>
# ### [Networking Concepts](#networkConcepts)

# %% [markdown]
# - [Network Time Protocol - NTP](#NetworkTimeProtocolNTP) <br/><br/>
#     - [Server](#NTPServer) <br/><br/>
#         - [Stratum Layers](#NTPStratumLayers) <br/><br/>
#             - [``0``](#NTPStratumLayers) <br/><br/>
#             - [``1``](#NTPStratumLayers) <br/><br/>
#             - [``2``](#NTPStratumLayers) <br/><br/>
#         - [Conflguration](#NTPServerConflguration) <br/><br/>
#     - [Client](#NTPClient) <br/><br/>
#         - [Conflguration](#NTPClientConflguration) <br/><br/>
# - [Strategy](#NTPStrategy)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkConcepts"></a>
# ***
# ### Networking Concepts
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="NetworkTimeProtocolNTP"></a>
# ***
# ###### Network Time Protocol - NTP
# ***

# %% [markdown]
# All of the devices on our network have their own clock.

# %% [markdown]
# This would be every server, every router, every switch, every workstation, and every other device.

# %% [markdown]
# There is usually log files, authentication details, anything dealing with logging of information is all using the date and time that is gathered from this clock information.

# %% [markdown]
# So, having this synchronized across all of these devices is very important.

# %% [markdown]
# That would allow you to compare log files across multiple devices to track exactly what’s going on in your environment.

# %% [markdown]
# And, of course, you would like this to occur automatically.

# %% [markdown]
# You don’t want to have to go into every single device and update the clock or have to update the clock every time the device is rebooted.

# %% [markdown]
# Fortunately, we’re able to do this using ``NTP`` or the ``Network Time Protocol``.

# %% [markdown]
# This allows us to configure our devices with an NTP server and then they can check in to that NTP server to update their clocks on a regular basis.

# %% [markdown]
# This is an extremely accurate way of updating these clocks.

# %% [markdown]
# Usually, the accuracy is better than one millisecond when you’re updating the clocks with an NTP server on your local network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="NTPServer"></a>
# ***
# ###### NTP Server
# ***

# %% [markdown]
# If you’re configuring NTP on your network you may want to have an internal NTP server.

# %% [markdown]
# This is a server that is in charge of the clock for all of the devices that need to get updates.

# %% [markdown]
# As an NTP server, it does not modify its own time.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="NTPStratumLayers"></a>
# ***
# ###### NTP Stratum Layers
# ***

# %% [markdown]
# We can associate a value with an NTP server that designates how far it is away from the original time source.

# %% [markdown]
# We call these stratum layers in NTP.

# %% [markdown]
# That’s because the original reference clock would be ``stratum 0 server`` - this might be an atomic clock or a GPS clock that you’ve configured.

# %% [markdown]
# The next server away from stratum ``0`` would be a ``stratum 1 server``, which is going to be obtaining its timestamp from a stratum ``0`` server.

# %% [markdown]
# You might also have ``stratum 2 servers`` on your network, which are going to be receiving their timestamps from a stratum ``1`` server.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="NTPServerConflguration"></a>
# ***
# ###### NTP Server Conflguration
# ***

# %% [markdown]
# You can also use multiple NTP servers just in case one of those is not available.

# %% [markdown]
# If this NTP server is going to be on your own internal network you’ll need at least one NTP server to act as the clock source.

# %% [markdown]
# You’ll also specify in the configuration of that NTP server what stratum this device happens to be.

# %% [markdown]
# So, if a client has the choice of synchronizing itself with an NTP server that has a stratum level of ``2`` and another NTP server that has a stratum level of ``1`` it will choose to synchronize itself with the server that has the lower stratum number or the stratum level ``1``.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="NTPClient"></a>
# ***
# ###### NTP Client
# ***

# %% [markdown]
# An NTP client is a device that will request these times from the NTP server and then update their clocks accordingly.

# %% [markdown]
# Sometimes a device can be both an NTP client and an NTP server.

# %% [markdown]
# So it can update its time based on the time that may be available on a more accurate NTP server and then it can provide those updates to other NTP clients on your network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="NTPClientConflguration"></a>
# ***
# ###### NTP Client Conflguration
# ***

# %% [markdown]
# On your client workstations you generally would configure your NTP client, which may specify an IP address or the domain name of a particular NTP server.

# %% [markdown]
# And if this is inside of your network you may want to specify your own internal IP addresses.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="NTPStrategy"></a>
# ***
# ###### NTP Strategy
# ***

# %% [markdown]
# If you’re planning to configure this on your network then you need to decide what devices will be NTP clients, which will be NTP servers, and which devices may be both an NTP client and an NTP server.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
