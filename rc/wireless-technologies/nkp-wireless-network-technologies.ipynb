# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-network-concepts/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Network Concepts``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# <a id="topAdvancedNetworking"></a>
# ### [Networking Concepts](#networkConcepts)

# %% [markdown]
# - [Wireless Network Technologies](#networkConceptsWirelessNetworkTechnologies) <br/><br/>
# 	- ``802.11`` Networks [Frequency Range: ``2.4 GHz`` or ``5 GHz`` or Both] <br/><br/>
# 		- Channels [Groups of Frequencies - Numbered by IEEE] <br/><br/>
# 			- ``802.11`` Channel Bandwidths [Frequency Usage at a Particular Time] <br/><br/>
#                 - ``802.11a`` <br/><br/>
#                     - Modulation ``20 MHz`` <br/><br/>
#                 - ``802.11b`` <br/><br/>
#                     - Modulation ``22 MHz`` <br/><br/>
#                 - ``802.11g`` [Same Frequency as ``802.11b``]
#                     - Modulation ``20 MHz`` <br/><br/>
#                 - ``802.11n`` <br/><br/>
#                     - Modulation ``20 MHz`` <br/><br/>
#                     - Modulation ``40 MHz`` [Two Contiguous ``20 MHz`` Bonded Channels] <br/><br/>
#                         - ``2.4 GHz`` [``40 MHz`` Channel uses ``>`` 80% of Available Frequencies] <br/><br/>
#                 - ``802.11ac`` <br/><br/>
#                     - Modulation ``40 MHz`` <br/><br/>
#                         - Minimum Channel Bandwidth <br/><br/>
#                     - Modulation ``80 MHz`` <br/><br/>
#                         - Required for ``802.11ac`` Stations <br/><br/>
#                     - Modulation ``160 MHz`` <br/><br/>
#                         - Contiguous Channels or Non-contiguous Bonded Channels <br/><br/>
# 	- Band Selection & Bandwidth [Available Frequencies ``2 GHz`` & ``5 GHz`` Range] <br/><br/>
#     ![Summary](https://github.com/SeanOhAileasa/SeanOhAileasa/blob/master/rc/nkp/802-11-spectrum-2-4-ghz-5-ghz-.png?raw=true) <br/><br/>
#     - ``802.11n`` [Before ``n`` Only Send Single Stream of Information] <br/><br/>
#         - Multiple Input and Multiple Output (MIMO) [Introduced in ``802.11n``] <br/><br/>
#             - Send Multiple Streams of Information [Same Frequencies / Same Time] <br/><br/>
# 	- ``802.11ac``
#         - Multi-user Multiple Input and Multiple Output (MU-MIMO) <br/><br/>
#                 - Send to Multiple Users Simultaneously [Same Frequencies / Same Time] <br/><br/>
#             - Dependent on Numbers of Antennas [Include ``802.11n``] <br/><br/>
#                 - Used to Determine the Number of Available Streams <br/><br/>
#                     - (Antennas on Access Point) x (Antennas on Client): Total Streams <br/><br/>
#     - Antennas <br/><br/>
#         - ``802.11a`` - ``802.11b`` - ``802.11g`` (< ``802.11n``) <br/><br/>
#             - ``x1`` Antenna on Access Point (AP) | ``x1`` Antenna on Client <br/><br/>
#                 - Communication over Single Frequency [x1 Device to Other] <br/><br/>
#         - ``802.11n`` <br/><br/>
#             - MIMO [New Way to Communicate] <br/><br/>
#                 - Signal Bounce of Other Devices <br/><br/>
#                     - Data Reconstructed using Digital Signal Processing [End Device] <br/><br/>
#                 - One Group at a Time <br/><br/>
#         - ``802.11ac`` <br/><br/>
#             - MU-MIMO <br/><br/>
#                 - Multiple Streams to send Data to Multiple Clients [Same Frequency] <br/><br/>
#     - Wireless Access Points - AP [Wireless Router] <br/><br/>
#         - Power Level Controls <br/><br/>
#             - Consider Signal Sent Out [Software Configuration] <br/><br/>
#                 - Power Level Controls <br/><br/>
#             - Consider Receiver [Antenna] <br/><br/>
#                 - Turn Down Power on AP [Still Maintain Good Level of Communication] <br/><br/>
#         - Omnidirectional Antennas [Omni ``=`` *] <br/><br/>
#             - Distribute Signal Evenly All Sides of Antenna <br/><br/>
#                 - Central Location [AP] <br/><br/>
#                 - ``!=`` Focus Signal <br/><br/>
#             - Directional Antennas <br/><br/>
#                 - Single Direction [Send & Receive] <br/><br/>
#                 - Focused Signal [Transmission & Listenin] <br/><br/>
#                 - Performance Measured in ``dB`` <br/><br/>
#                     - Double Power every ``3dB`` of Gain <br/><br/>
#                         - Yagi Antennas <br/><br/>
#                             - Very Directional [High Gain] <br/><br/>
#                         - Parabolic Antennas [Curved Surface] <br/><br/>
#                             - Focus Signal to Single Point <br/><br/>
#         - Wireless Survey Tools [Signal Coverage] <br/><br/>
#             - Potential Interference <br/><br/>
#                 - Other AP [Other Wireless Devices] <br/><br/>
#             - Built-in Tools [3rd Party Tools] <br/><br/>
#             - Spectrum Analyser [Details at Every Frequency]

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkConcepts"></a>
# ***
# ### Networking Concepts
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkConceptsWirelessNetworkTechnologies"></a>
# ***
# ###### Wireless Network Technologies
# ***

# %% [markdown]
# There are a number of different technologies used to communicate over ``802.11`` networks.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### ``802.11`` Networks - Frequency Range: 2.4 GHz - 5 GHz
# ***

# %% [markdown]
# One big difference between different standards of ``802.11`` networks are the frequencies used to communicate.

# %% [markdown]
# Some ``802.11`` networks use the ``2.4 GHz`` frequency range, other ``802.11`` technologies will use the ``5 GHz`` frequency range.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Frequency Range: 2.4 GHz - 5 GHz - Channels
# ***

# %% [markdown]
# Instead of us having to remember the exact frequency in the ``2.4 GHz`` or ``5 GHz`` frequency range, the IEEE standards have grouped together these frequencies into channels.

# %% [markdown]
# It makes it very easy to reference when you're configuring a wireless access point.

# %% [markdown]
# If you're trying to make sure that multiple access points can communicate, you may want to choose channels that don't overlap with each other.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### ``802.11`` Networks - Bandwidth
# ***

# %% [markdown]
# Different ``802.11`` standards will use different bandwidths in these ``2.4 GHz`` and ``5 GHz`` frequency ranges.

# %% [markdown]
# This is the amount of frequency you're using at any particular time.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Bandwidth - Channels - ``802.11a`` (Modulation: 20 MHz) and ``802.11b`` (Modulation: 22 MHz)
# ***

# %% [markdown]
# ``802.11a`` and ``802.11b`` were introduced at effectively the same time. And they used very similar bandwidth.

# %% [markdown]
# ``802.11a`` uses 20 MHz (megahertz).

# %% [markdown]
# ``802.11b`` uses 22 MHz (megahertz).

# %% [markdown]
# The modulation used for these two standards was slightly different, but the overall amount of bandwidth being used was very similar between both of them.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Bandwidth - Channels - ``802.11g`` (Modulation: 20 MHz)
# ***

# %% [markdown]
# The introduction of ``802.11g`` also used the same frequencies as ``802.11b``.

# %% [markdown]
# But you can see that a change in the modulation also changed the bandwidth that that particular standard would use in the 2.4 GHz range.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Bandwidth - Channels - ``802.11n`` (Modulation: 20 MHz or 40 MHz - Bonded Channels)
# ***

# %% [markdown]
# We realise that if we wanted to increase the amount of data that we could send over these wireless networks that we would need to use more of these frequency ranges.

# %% [markdown]
# And with ``802.11n``, we have the choice of either:
#
# i. 20 MHz or
#
# ii. doubling it to a 40 MHz channel bandwidth.

# %% [markdown]
# That means with ``802.11n`` running at 2.4 GHz, a 40 MHz channel would use 80% of the available frequencies in the 2.4 GHz range.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Bandwidth - Channels - ``802.11ac`` (Modulation: 20 MHz or 80 MHz [Required] or 160 MHz)
# ***

# %% [markdown]
# To avoid some of those bandwidth shortcomings with 2.4 GHz, the ``802.11ac`` standard uses 5 GHz.

# %% [markdown]
# It will use at a minimum 40 MHz of a channel bandwidth.

# %% [markdown]
# It can also increase that to 80 MHz channel bandwidth and that's required for ``802.11ac`` stations.

# %% [markdown]
# And if you even wanted to increase it to 160 MHz bandwidth, you would be able to move that much more data through your ``802.11ac`` network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Band Selection & Bandwidth - 2 GHz - 5 GHz
# ***

# %% [markdown]
# The following is a chart that shows the differences in the available frequencies in the 2.4 GHz range and the available frequencies in the 5 GHz range.

# %% [markdown]
# This also shows you how you're able to increase the different channel widths to use more frequencies at the same time.

# %% [markdown]
# If we first look at the 2.4 GHz range, we see the different channels that have been assigned by the IEEE.

# %% [markdown]
# And these are three channels that don't overlap with each other channels 1, channel 6 and channel 11.

# %% [markdown]
# And you can see the range with these 20 MHz blocks for each one of these.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# For 5 GHz, you can see that we have many more blocks of 20 MHz channel bandwidth available.

# %% [markdown]
# Anything that is not read is available bandwidth that you can use in 5 GHz.

# %% [markdown]
# So you could see a large difference in available bandwidth when you move up to the 5 GHz ranges.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# But of course, some of these 5 GHz standards allow you to have larger channel bandwidth.

# %% [markdown]
# So you can group together and have 40 MHz channel bandwidths 80 MHz or in the case of ``802.11ac`` , you can use 160 MHz channels to be able to move data over that wireless network.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Multiple Input and Multiple Output (MIMO) - ``802.11n``
# ***

# %% [markdown]
# Not only did we change the amount of frequencies that we were using with these channel bandwidths, we also changed the way that we were sending data over these wireless networks.

# %% [markdown]
# Prior to ``802.11n`` we would simply send a single stream of information between point A and point B.

# %% [markdown]
# But ``802.11n`` introduced a new way to send data called MIMO - Multiple Input and Multiple Output.

# %% [markdown]
# That allows us to send multiple streams of information over exactly the same frequencies at the same time. Prior to this, we weren't able to accomplish that.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Multi-user Multiple Input and Multiple Output (MU-MIMO) - ``802.11ac``
# ***

# %% [markdown]
# With ``802.11ac``, we improved on MIMO by introducing Multi-user MIMO (MU-MIMO), where we could send data to multiple users simultaneously over the same frequencies.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### MIMO - Antennas
# ***

# %% [markdown]
# The ability to provide this multiple input multiple output was very dependent on the number of antennas that you might have available on a particular device.

# %% [markdown]
# So for ``802.11n`` and ``802.11ac``, you may see the:
#
#
# - number of antennas on an access point;
#
#
# - number of antennas on a client;
#
#
# - streams available documented somewhere on that particular device.

# %% [markdown]
# For example, if you see ``2x2:2``, this means there's two antennas on the access point with two antennas on the client, and it can support two total (simultaneous) streams.
#
# $$(Antennas\space AP)\times(Antennas\space Client):Number\space of\space Streams$$

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Antennas - ``802.11a`` - ``802.11b`` - ``802.11g`` (< ``802.11n``)
# ***

# %% [markdown]
# On ``802.11``, ``a``, ``b`` and ``g`` there was one antenna on the access point and one antenna on the client.

# %% [markdown]
# The communication occurred over a single frequency from one device to the other.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ######  Antennas - MIMO - ``802.11n``
# ***

# %% [markdown]
# When we introduced MIMO, with ``802.11n``, this introduced a completely new way to communicate.

# %% [markdown]
# With MIMO we need signal diversity - need a way for some signals to bounce off of other devices and make their way to the device on the other side.

# %% [markdown]
# There's something in the middle and it's bouncing the signal off - the data on the other end is reconstructed using digital signal processing.

# %% [markdown]
# This allows you to send multiple streams of information between devices, and you're able to do it over exactly the same frequency.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# With MIMO, we could really increase the amount of throughput between devices because if both devices supported multiple streams, you can begin to send lots of data between those.

# %% [markdown]
# The MIMO that was included with ``802.11n`` could only send one grouping at a time.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So it could send data down to this laptop, it could then change and send data to a mobile device and then send data to a television.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# But it could not do all three of these simultaneously.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Antennas - MU-MIMO - ``802.11ac``
# ***

# %% [markdown]
# In ``802.11ac`` we were provided with multi user MU-MIMO, which meant that we could use multiple streams to send data over the same frequency but we could do it to multiple clients simultaneously.

# %% [markdown]
# So you could have a couple of streams of data going to a laptop, you could have a stream of information going to your mobile device, and another stream going to this television all using the same frequencies simultaneously on this ``802.11ac`` network.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Antennas - Power Level Controls
# ***

# %% [markdown]
# If you live in an apartment building, or you work in an office building with many different companies, you've probably seen a number of different wireless access points show up on a list of available networks. Because of this, you may want to consider how much signal you're sending out for your access points.

# %% [markdown]
# This is usually a configuration change that you could make inside the software configuration of a wireless access point or wireless router.

# %% [markdown]
# This may take a little bit of survey work while you walk around with a mobile device and determine how much of the wireless signal you're able to hear between the access point and your mobile device.

# %% [markdown]
# With some devices, you may even have an option as to the type of antenna you use, especially with a desktop computer and by changing the type of antenna, you may be able to turn down the amount of power on your access point, but still maintain a good level of communication between those two devices.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Antennas - Omnidirectional Antennas
# ***

# %% [markdown]
# If you've ever purchased a wireless access point, or wireless router, it probably came with antennas that look a lot like these.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# These are omnidirectional antennas, and they are some of the most common that you'll find on these devices.

# %% [markdown]
# We call these antennas omni directional because they distribute the wireless signal evenly on all sides of that antenna.

# %% [markdown]
# This would allow you to put the wireless access point in a central location. And you'd have effectively the same signal strength on all sides of that access point.

# %% [markdown]
# You may run into a challenge however, if your access point is on one side or the other of where you need the signal to go. In those cases, you may want to use a more directional antenna.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Antennas - Directional Antennas
# ***

# %% [markdown]
# A directional antenna would allow you to focus the signal to go into a particular direction.

# %% [markdown]
# So if you're needed to send information between buildings, or you had an access point at one end of the hall, and you needed to provide signal across the rest of the hallway, you may want to use a directional antenna.

# %% [markdown]
# We usually measure the performance of these antennas in decibels so if you have an antenna that doubles the amount of effective power than we say that you're doubling this by 3dB.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Directional Antennas - Yagi (High Gain) Antennas
# ***

# %% [markdown]
# One type of high gain directional antenna is the Yagi antenna, where you have the single antenna and multiple reflectors along the side that allow you to focus the signal.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Directional - Parabolic Antennas
# ***

# %% [markdown]
# Another type of directional antenna is the parabolic antenna.

# %% [markdown]
# This allows you to reflect a signal off of a curved surface and reflected into a single feed horn allowing you a very good way to have a directional signal between two devices.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Wireless Survey Tools
# ***

# %% [markdown]
# If you're doing any type of wireless communication on your network, you may need some way to provide a survey.

# %% [markdown]
# You may need to walk around with a mobile device and be able to understand the wireless characteristics in your area. It will not only be able to show you the coverage of signal as you walk around, but you may be able to find certain spots of interference that may be coming from other access points, or other wireless devices.

# %% [markdown]
# You may find a number of built in tools in the operating system that you're using.

# %% [markdown]
# But a number of third party products may provide you with some additional insight into exactly what's happening on your wireless network.

# %% [markdown]
# If you're doing a lot of wireless installations, and you need a very precise view of exactly what's going on at every frequency of the ``802.11`` wireless range, you may want to invest in a spectrum analyzer that can show you details of exactly what's happening at every frequency.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
