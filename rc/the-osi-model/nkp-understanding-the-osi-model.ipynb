# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-network-concepts/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Understanding the OSI Model``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# <a id="topAdvancedNetworking"></a>
# ### [Understanding the OSI Model](#networkConcepts)

# %% [markdown]
# - OSI Protocol Suite (OSI Model built based on these OSI Protocols) <br/>
# 	- Guide [thus the term "Model"] <br/>
# 		- The OSI Model <br/>
# 			- Layer 1 Physical Layer [``!=``Protocols] <br/>
# 				- Network Physics [Signaling / Cabling / Connectors] - [NIC - Cable - Hub] <br/>
# 					- Problems <br/>
# 						- Fix Cabling - Punch-downs <br/>
# 						- Run Loopback Test - Test and/or replace Cables - Swap Adapter Cards <br/>
# 			- Layer 2 Data Link Layer ["switching"] - [Frame - MAC Address - EUI-48 - EUI-64 - Switch] <br/>
# 				- Network Basic Language [Foundation of Communication] <br/>
# 				- Data Link Control (DLC) Protocols <br/>
# 					- Media Access Control (MAC) Address on an Ethernet Network <br/>
# 			- Layer 3 Network Layer ["routing"] - [IP Address - Router - Packet] <br/>
# 				- Internet Address (IP) <br/>
# 					- Fragments Frames [Traverse different Networks]
# 					- IP Fragmentation <br/>
# 						- Multiples of ``8``
# 							- No. Fragmentation offset bits in IP Header <br/>
# 			- Layer 4 Transport Layer ["post office"] - [TCP Segment - UDP Datagram] <br/>
# 				- Parcels & Letters <br/>
# 				- Transmission Control Protocol (TCP) or User Datagram Protocol (UDP) <br/>
# 			- Layer 5 Session Layer - [Control Protocols - Tunnelling Protocols] <br/>
# 				- Communication Management between Devices [Start / Stop / Restart] <br/>
# 					- Duplex [Full / Half] <br/>
# 			- Layer 6 Presentation Layer [Often combined with Application Layer] - [SSL / TLS] <br/>
# 				- Character Encoding <br/>
# 				- Application Encryption <br/>
# 			- Layer 7 Application Layer [User Sees] <br/>
# 				- HTTP <br/>
# 				- FTP <br/>
# 				- DNS <br/>
# 				- POP3 <br/>
# 	        ![Image: OSI Model](https://github.com/SeanOhAileasa/SeanOhAileasa/blob/master/rc/nkp/osi-model.png?raw=true) <br/>
# 			- Wireshark <br/>

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkConcepts"></a>
# ***
# ### Understanding the OSI Model
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkConceptsUnderstandingtheOSIModel"></a>
# ***
# ###### Understanding Open Systems Interconnection (OSI) Model
# ***

# %% [markdown]
# The OSI model is the Open Systems Interconnection reference model, but we often simply refer to it as the OSI model.

# %% [markdown]
# The OSI model is a guide we use to help understand the flow of data as it goes across the network.

# %% [markdown]
# This model is not intended as a strict representation, but instead is an overall guide to understand exactly how the data is flowing. Some places may put a particular component in OSI layer two, or OSI layer three, and indeed, it might overlap just a bit between both of those layers. Don't get too wrapped up in the details, you should instead be looking at a very broad view of the data as it's flowing from an application onto the network and back again.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### OSI Protocol Suite (OSI Model built based on these OSI Protocols)
# ***

# %% [markdown]
# Might also see a reference to a set of protocols called the OSI protocol suite.

# %% [markdown]
# The OSI protocol suite isn't something you'd really find on today's networks.

# %% [markdown]
# This OSI model was built based on the design of these OSI protocols, but although the OSI protocols don't exist anymore, we continue to use the OSI model.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### The OSI Model
# ***

# %% [markdown]
# As we step through the OSI model, you'll start to see certain protocols that exist or live at certain layers of the OSI model.

# %% [markdown]
# If you're working in information technology, you'll almost certainly make references to this model.  And in some cases, you'll make references multiple times a day to certain aspects of the OSI model. It allows different parts of the organisation to reference very broadly how a particular application flow is occurring. And if there's any problems, you can all specify whether the problem might be at layer three, layer four, and layer seven. And everyone in the organisation will know exactly what you mean when you reference those particular OSI layers.

# %% [markdown]
# Roll into a single sentence, you would remember ***All People Seem To Need Data Processing***, which refers to application, presentation, session, transport, network, data link and physical in that order.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### The OSI Model - Layer 1 Physical Layer
# ***

# %% [markdown]
# Let's start at the bottom of the OSI model with the physical layer.

# %% [markdown]
# The physical layer is where everything begins and ends on the network.

# %% [markdown]
# It is the signal that transports our traffic across the network, you're not really dealing with a lot of protocols at the physical layer, we often refer to the physical layer as referring to cables or fibre because that's where the signal is for our network.

# %% [markdown]
# If someone says that you're having a physical layer problem, they mean that there's a cable that's bad or punched out that needs to be repaired, you would commonly run loopback tests, replace cables and swap adapter cards to help troubleshoot a problem at OSI layer one or the physical layer.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### The OSI Model - Layer 2 Data Link Layer (Data Link Control (DLC) Protocols on an Ethernet Network)
# ***

# %% [markdown]
# Layer two of the OSI model is the data link layer.

# %% [markdown]
# This is the most fundamental communication that occurs across our network.

# %% [markdown]
# We commonly think of the data link layer as having data link control (DLC) protocols on an Ethernet network.

# %% [markdown]
# The data link layer is referencing the MAC addresses that are communicating on the network.

# %% [markdown]
# So if you're dealing with something that is switching or bridging or having two devices communicate to each other using these MAC addresses, then we usually refer to this as being an OSI layer two.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### The OSI Model - Layer 3 Network Layer (Routing Layer [Internet Address IP])
# ***

# %% [markdown]
# Layer three of the OSI model is the network layer.

# %% [markdown]
# And we often refer to this as the routing layer.

# %% [markdown]
# This is an internet protocol layer.

# %% [markdown]
# So if you're dealing with any type of IP address, you're really referring to something occurring at the OSI layer three.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### The OSI Model - Layer 3 Network Layer (Routing Layer [Internet Address IP]) - IP Fragmentation
# ***

# %% [markdown]
# This layer is also responsible for fragmenting some of the data within these frames that are going between these IP devices so that they're able to traverse different networks.

# %% [markdown]
# With IP fragmentation, you may have some data that needs to go through a network and this data is 44 bytes long in this particular example, but this traffic may need to go through a network that can support that size of a packet.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In that particular case, the packet is fragmented into smaller pieces, and those smaller pieces are sent through the network.

# %% [markdown]
# OSI layer three is responsible for fragmenting this information. So if you need to create smaller packets to get the data through the network, this is all occurring at the network layer.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### The OSI Model - Layer 4 Transport Layer
# ***

# %% [markdown]
# The information that appears in our browser window doesn't appear at one time with one packet across the network. It usually takes many packets all put together to be able to build one screen in our browser.

# %% [markdown]
# Good example of how this occurs is at OSI layer four, or the transport layer.

# %% [markdown]
# If we need to get this Google screen across the network, it's split into smaller pieces sent across the network and then is built in our browser as that information arrives.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### The OSI Model - Layer 4 Transport Layer - Transmission Control Protocol (TCP) or User Datagram Protocol (UDP)
# ***

# %% [markdown]
# The most common protocols that accomplish this transferring of information across the network is the TCP or Transmission Control Protocol, or UDP, the User Datagram Protocol.

# %% [markdown]
# If you ever hear anyone referring to layer four or layer four protocol, they're almost always referring to TCP or UDP.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### The OSI Model - Layer 5 Session Layer (Control Protocols - Tunnelling)
# ***

# %% [markdown]
# Once you're going to do OSI layers five, six, and seven, you're dealing with the way that applications communicate across the network.

# %% [markdown]
# Many applications handle their own process of starting a communication and ending a communication and all of this occurs at layer five or the session layer.

# %% [markdown]
# This is also the layer where you'll see certain control protocols communicate between application endpoints, or if there's any tunnelling, it will occur at this layer five or the session layer.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### The OSI Model - Layer 6 Presentation Layer (Character Encoding - Encrypted or Decrypted)
# ***

# %% [markdown]
# The layer just before you're able to see the application is layer six or the presentation layer.

# %% [markdown]
# If there's any character encoding, it will occur at this layer and if any of the data needs to be encrypted or decrypted, it usually occurs in the application at this layer six.

# %% [markdown]
# Many of the applications that work at layer six may also be working at layer seven. So it's not uncommon to see many application protocols sharing both layer six and layer seven simultaneously.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### The OSI Model - Layer 7 Application Layer
# ***

# %% [markdown]
# Layer seven is the application layer. It's the layer that we can see which might be a browser window, we might be transferring a file or we might be downloading some mail.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### The OSI Model - Summary
# ***

# %% [markdown]
# So here's a summary of this OSI model at OSI layer one the physical layer, we have cables, we've got our fibre optics, and we have the signal that goes across that network medium.

# %% [markdown]
# OSI layer two is the data link layer where we might find MAC addresses and the frames of communication and all of our switching decisions take place at this OSI layer two.

# %% [markdown]
# At OSI layer three, we're dealing with IP addresses, so any routing decisions that are being made are referring to the OSI layer three address to be able to make those decisions.

# %% [markdown]
# Within this IP communication is OSI layer four the transport layer where you'll find the TCP and the UDP protocols.

# %% [markdown]
# Control protocols and tunnelling information will occur in the application OSI layer five.

# %% [markdown]
# The session layer, and OSI layer six the presentation layer handles a lot of the communication that will be encrypted or decrypted for our application.

# %% [markdown]
# And finally, OSI layer seven is the layer that we see as we're using these applications.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Wireshark
# ***

# %% [markdown]
# One place where you can really start to see this OSI model laid out is inside of Wireshark.

# %% [markdown]
# This is an application that will grab packets from the network and display those to you on the screen in a human readable form.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If we were to look at this particular packet capture where we've gathered a number of packets.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Examining a single packet in a detailed view.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# And this is the hex breakdown of that same packet.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Looking at the single packet we know we start at the top here with ``Frame 88``, which happens to have ``2005 bytes on the wire``.

# %% [markdown]
# This is the physical layer where we gathered the information from the network.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The next layer is layer two, the data link layer which shows the MAC addresses associated with the source and the destination of this traffic flow.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# OSI layer three the network layer shows IP addresses.

# %% [markdown]
# And in this particular case, it shows the name and the IP address of both the source and the destination.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# OSI layer four is the next layer the transport layer. And I mentioned that we'll be using either TCP or UDP to communicate. And in this particular case, it's the Transmission Control Protocol. And we can see the source port numbers and the destination port numbers for this communication.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# And lastly, for this particular packet capture, we've got layers five, six and seven that are rolled up within the secure socket layer.

# %% [markdown]
# So our encryption and decryption occurring at layer six are the presentation layer and ultimately the information we see at layer seven the application layer will be everything above that particular data stream.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Layer 1: To summarise that individual packet, we were able to see what was gathered from the electrical signals.

# %% [markdown]
# - Layer 2: Able to gather the MAC addresses associated with this Ethernet communication.

# %% [markdown]
# - Layer 3: Saw the IP addresses that were used to send information back and forth to this Google mail server.

# %% [markdown]
# - Layer 4: We know that there was TCP communication and we saw exactly what port numbers were used.

# %% [markdown]
# - Layer 5: There was session information that was linking the presentation layer to the transport layer.

# %% [markdown]
# - Layer 6: And it was the presentation layer that was performing the SSL encryption.

# %% [markdown]
# - Layer 7: And if we were looking at our browser as this traffic went by, we would have been in the Google Mail screen sending information back and forth using this application at OSI layer seven.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
