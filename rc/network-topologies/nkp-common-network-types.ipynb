# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-network-concepts/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Network Concepts``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# <a id="topAdvancedNetworking"></a>
# ### [Networking Concepts](#networkConcepts)

# %% [markdown]
# - [Common Network Types](#networkConceptsCommonNetworkTypes) <br/><br/>
# 	- Local Area Network - LAN <br/><br/>
#         - Ethernet <br/><br/>
#         - Wireless ``802.11`` <br/><br/>
# 	- Wireless LAN - WLAN [Exclusive] <br/><br/>
#         - ``802.11`` <br/><br/>
#             - Access Points [Expand] <br/><br/>
# 	- Metropolitan Area Network - MAN <br/><br/>
#         - City Network [Government Ownership] <br/><br/>
#             - ``>`` LAN [``<`` WAN] <br/><br/>
# 	- Wide Area Network - WAN <br/><br/>
#         - ``>`` MAN [Connects LANs across a Distance] <br/><br/>
#             - Point-to-point Serial Connection [Technology] <br/><br/>
#             - Multiprotocol Label Switching (MPLS) Connection [Technology] <br/><br/>
#             - Satellite Connection [Technology] <br/><br/>
#                 - Non-terrestial Links <br/><br/>
# 	- Campus Area Network - CAN <br/><br/>
#         - Building in Office Block [College Campus] <br/><br/>
#             - Limited Geographical Area <br/><br/>
#                 - Fiber Connection [Technology] <br/><br/>
#                     - No 3rd Party Provider [Own Fiber in Ground] <br/><br/>
#                 - High-speed Ethernet [Technology] <br/><br/>
# - [Connect Hard Drive](#connectHardDrive) <br/><br/>
#     - Network Attached Storage - NAS <br/><br/>
#         - Remote Shared Storage <br/><br/>
#             - File-level Access <br/><br/>
#                 - Change Part of File [Replace Entire File] <br/><br/>
#     - Storage Area Network - SAN <br/><br/>
#         - Extension of Computer [Look / Feel Local Storage Device] <br/><br/>
#             - Block-level Access [Efficient Reading & Writing] <br/><br/>
#                 - Change Part of File [Blocks Changed Only] <br/><br/>
#                     - ``!=`` Entire File <br/><br/>
#     - Requires a lot of Bandwidth (Reading / Writing) [NAS & SAN] <br/><br/>
#         - Connect via High-speed Network Topologies <br/><br/>
# - [Personal Area Network - PAN](#personalAreaNetworkPAN) <br/><br/>
#     - Private Network <br/><br/>
#         - Bluetooth [Device Connection] <br/><br/>
#         - Infrared [Device Connection] <br/><br/>
#         - Near-Field Communication - NFC [Device Connection]

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkConcepts"></a>
# ***
# ### Networking Concepts
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkConceptsCommonNetworkTypes"></a>
# ***
# ###### Common Network Types
# ***

# %% [markdown]
# Most common network types is the local area network or the LAN.

# %% [markdown]
# Really referring to the network that might be inside of a single building, or one that spans a group of buildings in a centralised area.

# %% [markdown]
# Usually think of local area networks as being high speed because all of the devices communicating are in this local area.

# %% [markdown]
# Two common types of local area networks would be:
#
# i. ``Ethernet`` networks
#
#
# ii. ``802.11`` wireless networks.

# %% [markdown]
# If using a network that has a slower bandwidth than an ``Ethernet`` or an ``802.11`` network, then probably not on a local area network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Wireless LAN
# ***

# %% [markdown]
# Referring exclusively to an ``802.11`` wireless network, might want to refer to this as a WLAN or wireless LAN.

# %% [markdown]
# Usually, a wireless LAN would be inside of a building or a limited geographical area.

# %% [markdown]
# Can expand the size of this wireless LAN by adding additional access points.

# %% [markdown]
# Could be on a single wireless LAN that might be in a downtown area, or in a large campus.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Metropolitan Area Network (MAN)
# ***

# %% [markdown]
# A network that might connect to locations in a large city might be a metropolitan area network.

# %% [markdown]
# This network is much larger than a local area network, but doesn't have the wide scope that you would find in a wide area network.

# %% [markdown]
# Traditionally been ``non-Ethernet`` topologies that have been used for Metropolitan Area Networks, but most MAN's these days are connecting locations with metropolitan ``Ethernet`` - end stations would simply receive an ``Ethernet`` connection on both sides.

# %% [markdown]
# It's common to see metropolitan area networks being used by governments.

# %% [markdown]
# Since they already own the right of way, it's relatively easy to put fibre in the ground and connect all of their locations together using this metropolitan area network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Wide Area Network (WAN)
# ***

# %% [markdown]
# Need to connect to locations that are outside of the metropolitan area, then probably going to need a wide area network.

# %% [markdown]
# This would connect devices that are within the same state, the same country, or even between different countries.

# %% [markdown]
# Usually a much larger area than a local area network or metropolitan area network, but also usually have slower bandwidth available when referring to a wide area network.

# %% [markdown]
# There are many different ways to provide wide area network connectivity, it might be a point-to-point serial connection or an Multiprotocol Label Switching (MPLS) connection.

# %% [markdown]
# Might use satellite communication for non-terrestrial links.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Campus Area Network (CAN)
# ***

# %% [markdown]
# If the company you work for occupies multiple buildings inside of an office park, or you've ever taken a class on a college campus, then you're probably familiar with a CAN or campus area network.

# %% [markdown]
# This campus is usually a group of buildings that are relatively close to each other, at least close enough that you could extend network connections so that all of the buildings would effectively be on the same network.

# %% [markdown]
# Very common in these campus area networks to connect all of these buildings together with fibre and be able to run high speed ``Ethernet``, especially when you consider there may be many people inside one building that need to access resources in another building.

# %% [markdown]
# So it makes sense to have the highest line rates you can between these buildings.

# %% [markdown]
# One of the nice things about a campus area network is that you usually have the ability to put your own conduit in between the buildings and run your own fibre.

# %% [markdown]
# Do not have to pay a monthly cost to a service provider, you can simply connect two switches at the end of the fibre and now your two buildings are connected directly with each other.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="connectHardDrive"></a>
# ***
# ###### Connect Hard Drive
# ***

# %% [markdown]
# Plugging in a hard drive to your network, may be connecting a NAS or Network Attached Storage.

# %% [markdown]
# This is a type of storage that allows us to store files across the network on this remote storage device and we usually refer to this as file-level access.

# %% [markdown]
# If you need to change part of a file, you need to replace the entire file on the Network Attached Storage (NAS) device.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# A more advanced type of storage over the network is a SAN or Storage Area Network.

# %% [markdown]
# With a SAN that remote storage device is more of an extension of your computer, we refer to this as block-level access.

# %% [markdown]
# If you need to change part of a file, you simply change the blocks that have been changed, rather than rewriting the entire file on the storage device.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Both the network attached storage and the storage area network require enough bandwidth to be able to support the reading and writing of this data across the network.

# %% [markdown]
# So it's very common to connect these types of storage systems over high-speed network topologies.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="personalAreaNetworkPAN"></a>
# ***
# ###### Personal Area Network (PAN)
# ***

# %% [markdown]
# It's now very common for us to connect a lot of our personal devices together through a Personal Area Network (PAN).

# %% [markdown]
# For example, you can connect devices through Bluetooth, infrared or NFC connections.

# %% [markdown]
# It's very common to do this in an automobile - can integrate your phone with the audio output inside of your car.

# %% [markdown]
# Can have a wireless headset that communicates to your mobile phone through Bluetooth connections.

# %% [markdown]
# A number of health monitoring devices can communicate to our other personal devices over these PANs.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
